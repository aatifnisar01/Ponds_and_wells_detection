# %% [markdown]
# # Necessary Steps

# %%
import json
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import shutil
from random import choice
import re
import csv
import zipfile
import pandas as pd
import glob
import math
import geopandas as gpd
from shapely.geometry import shape, Polygon, box
from PIL import Image
import requests
import time
from ultralytics import YOLO
from skimage.filters.rank import entropy
from skimage.morphology import disk
from skimage.util import img_as_ubyte
from shapely.ops import unary_union
from itertools import product
from samgeo import tms_to_geotiff
import pandas as pd

# %%
cd /home/core-stack/Documents/Ponds
# Out:
# /home/core-stack/Documents/Ponds

# %%
pwd = os.getcwd()
pwd
# Out:
# '/home/core-stack/Documents/Ponds'

# %%
import ee
ee.Authenticate()
ee.Initialize(project='ee-corestackdev')

# %% [markdown]
# # Paths and Args

# %%
# Zoom level 
zoom_level = 17 

# Folder paths where you want to save image tiles
image_dir = "Data/Zoom17/TRY"

# Scale of image tile
scale = 1           # scale of 1 = 256*256 dimensional image

# load trained model
model_path = "Models/Ponds_best.pt"

# CSV file name where masks of detected object will be saved
csv_file = "CSV_Output/TRY.csv"

# Entropy threshold needed to calculate entropy (only in wet ponds case)
entropy_threshold = 2.5

# %% [markdown]
# # Download Data for Inference

# %%
def lat_to_pixel_y(lat, zoom):
    sin_lat = math.sin(math.radians(lat))
    pixel_y = (0.5 - math.log((1 + sin_lat) / (1 - sin_lat)) / (4 * math.pi)) * (2 ** (zoom + 8))
    return int(round(pixel_y))

def lon_to_pixel_x(lon, zoom):
    pixel_x = ((lon + 180) / 360) * (2 ** (zoom + 8))
    return int(round(pixel_x))

def pixel_x_to_lon(pixel_x, zoom):
    return (pixel_x / (2 ** (zoom + 8))) * 360 - 180

def pixel_y_to_lat(pixel_y, zoom):
    n = math.pi - 2 * math.pi * pixel_y / (2 ** (zoom + 8))
    return math.degrees(math.atan(math.sinh(n)))

def lat_lon_from_pixel(lat, lon, zoom, scale):
    tile_width_deg = pixel_x_to_lon(256, zoom) - pixel_x_to_lon(0, zoom)
    new_lon = lon + (tile_width_deg * scale)
    new_pixel_y = lat_to_pixel_y(lat, zoom) + (256 * scale)
    new_lat = pixel_y_to_lat(new_pixel_y, zoom)
    return new_lat, new_lon
    
def divide_tiff_into_chunks(chunk_size, output_dir, zoom, top_left_lat, top_left_lon):
    input_image_path = os.path.join(output_dir, 'field.tif')
    image = Image.open(input_image_path)
    width, height = image.size

    # Calculate tile numbers from coordinates
    top_left_x_tile = int(lon_to_pixel_x(top_left_lon, zoom) / 256)
    top_left_y_tile = int(lat_to_pixel_y(top_left_lat, zoom) / 256)

    os.makedirs(os.path.join(output_dir, "chunks"), exist_ok=True)

    for i in range(0, width, chunk_size):
        for j in range(0, height, chunk_size):
            box = (i, j, i + chunk_size, j + chunk_size)
            chunk = image.crop(box)
            x_tile = top_left_x_tile + (i // chunk_size)
            y_tile = top_left_y_tile + (j // chunk_size)
            # Save with tile numbers instead of coordinates
            chunk.save(os.path.join(output_dir, "chunks", f'tile_{zoom}_{x_tile}_{y_tile}.tif'))
    print("Image has been split into chunks correctly.")

            
def download(coords, output_dir, zoom, scale):
    """Improved download function that handles both points and bboxes"""
    # Check if input is a single point (lat, lon) or bbox [min_lat, min_lon, max_lat, max_lon]
    if len(coords) == 2:  # It's a single point
        lat, lon = coords
        # Create a bbox around the point using the scale
        new_lat, new_lon = lat_lon_from_pixel(lat, lon, zoom, scale)
        bbox = [min(lat, new_lat), min(lon, new_lon), max(lat, new_lat), max(lon, new_lon)]
    else:  # It's already a bbox
        bbox = coords
    
    # Rest of your download function remains the same
    min_lon = min(bbox[1], bbox[3])
    max_lon = max(bbox[1], bbox[3])
    min_lat = min(bbox[0], bbox[2])
    max_lat = max(bbox[0], bbox[2])
    
    # Calculate the exact tile boundaries (fixed missing parentheses)
    tile_x_min = math.floor(lon_to_pixel_x(min_lon, zoom) / 256)
    tile_x_max = math.ceil(lon_to_pixel_x(max_lon, zoom) / 256)
    tile_y_min = math.floor(lat_to_pixel_y(max_lat, zoom) / 256)  # Note: y tiles increase downward
    tile_y_max = math.ceil(lat_to_pixel_y(min_lat, zoom) / 256)
    
    # Calculate the exact geographic bounds of the tile area
    exact_min_lon = pixel_x_to_lon(tile_x_min * 256, zoom)
    exact_max_lon = pixel_x_to_lon(tile_x_max * 256, zoom)
    exact_min_lat = pixel_y_to_lat(tile_y_max * 256, zoom)
    exact_max_lat = pixel_y_to_lat(tile_y_min * 256, zoom)
    
    corrected_bbox = [exact_min_lon, exact_min_lat, exact_max_lon, exact_max_lat]
    print(f"Downloading tiles for exact bbox: {corrected_bbox}")
    
    os.makedirs(os.path.join(output_dir, "chunks"), exist_ok=True)
    tms_to_geotiff(output=os.path.join(output_dir, "field.tif"), 
                  bbox=corrected_bbox, 
                  zoom=zoom, 
                  source='Satellite', 
                  overwrite=True)
    
    # Modify the divide function to use exact coordinates
    divide_tiff_into_chunks(256, output_dir, zoom, exact_max_lat, exact_min_lon)

def divide_tiff_into_chunks_improved(chunk_size, output_dir, zoom, top_left_lat, top_left_lon):
    """Improved version that maintains better geographic alignment"""
    input_image_path = os.path.join(output_dir, 'field.tif')
    image = Image.open(input_image_path)
    width, height = image.size

    # Calculate the geographic position of each pixel
    lon_per_pixel = (pixel_x_to_lon(1, zoom) - pixel_x_to_lon(0, zoom))
    lat_per_pixel = (pixel_y_to_lat(1, zoom) - pixel_y_to_lat(0, zoom))

    for i in range(0, width, chunk_size):
        for j in range(0, height, chunk_size):
            # Calculate exact geographic coordinates for this chunk
            chunk_min_lon = top_left_lon + (i * lon_per_pixel)
            chunk_max_lat = top_left_lat + (j * lat_per_pixel)
            
            box = (i, j, i + chunk_size, j + chunk_size)
            chunk = image.crop(box)
            
            # Save with geographic coordinates in filename
            chunk.save(os.path.join(output_dir, "chunks", 
                      f'tile_{zoom}_{chunk_min_lon:.6f}_{chunk_max_lat:.6f}.tif'))

                  
def get_n_boxes(lat, lon, n, zoom, scale):
    diagonal_lat_lon = [(lat, lon)]
    for _ in range(n):
        pixel_x = lon_to_pixel_x(lon, zoom) + (256 * scale)
        new_lon = pixel_x_to_lon(pixel_x, zoom)
        pixel_y = lat_to_pixel_y(lat, zoom) + (256 * scale)
        new_lat = pixel_y_to_lat(pixel_y, zoom)
        diagonal_lat_lon.append((new_lat, new_lon))
        lat, lon = new_lat, new_lon
    return diagonal_lat_lon

def get_points(roi, zoom, scale):
    bounds = roi.bounds().coordinates().get(0).getInfo()
    lons = sorted([coord[0] for coord in bounds])
    lats = sorted([coord[1] for coord in bounds])
    starting_point = (lats[-1], lons[0])
    min_pixel = [lon_to_pixel_x(lons[0], zoom), lat_to_pixel_y(lats[0], zoom)]
    max_pixel = [lon_to_pixel_x(lons[-1], zoom), lat_to_pixel_y(lats[-1], zoom)]
    iterations = math.ceil(max(abs(min_pixel[0] - max_pixel[0]), abs(min_pixel[1] - max_pixel[1])) / (256 * scale))
    points = get_n_boxes(starting_point[0], starting_point[1], iterations, zoom, scale)
    intersect_list = []
    print(f"Generated {len(points)} points")
    for point in points:
        bottom_right = lat_lon_from_pixel(point[0], point[1], zoom, scale)
        rectangle = ee.Geometry.Rectangle([(point[1], point[0]), (bottom_right[1], bottom_right[0])])
        if roi.geometry().intersects(rectangle, ee.ErrorMargin(1)).getInfo():
            intersect_list.append(point)
    return intersect_list

# %%
top_left = [23.127684562095336, 84.84800574153135]
bottom_right = [23.114998445439248, 84.88414127220975]
rectangle = ee.Geometry.Rectangle([top_left[1], bottom_right[0], bottom_right[1], top_left[0]])
roi = ee.FeatureCollection([ee.Feature(rectangle)])

print("Area of the Rectangle: ", rectangle.area().getInfo()/1e6, "sq km")
points = get_points(roi, zoom_level, 16)
print(f"Running for {len(points)} points...")

#roi = ee.FeatureCollection("projects/df-project-iit/assets/core-stack/tamil_nadu/theni/periyakulam/filtered_mws_theni_periyakulam_uid").filter(ee.Filter.stringContains("uid", "2_25099"))
# Out:
# Area of the Rectangle:  5.212770317570057 sq km
# Generated 2 points
# Running for 1 points...

# %%
for index, point in enumerate(points):
    output_dir = os.path.join(image_dir, str(index))
    download(point, output_dir, zoom_level, 16)
# Out:
# Downloading tiles for exact bbox: [84.847412109375, 23.08478515994372, 84.89410400390625, 23.127731365725918]
# Downloaded image 001/289
# Downloaded image 002/289
# Downloaded image 003/289
# Downloaded image 004/289
# Downloaded image 005/289
# Downloaded image 006/289
# Downloaded image 007/289
# Downloaded image 008/289
# Downloaded image 009/289
# Downloaded image 010/289
# Downloaded image 011/289
# Downloaded image 012/289
# Downloaded image 013/289
# Downloaded image 014/289
# Downloaded image 015/289
# Downloaded image 016/289
# Downloaded image 017/289
# Downloaded image 018/289
# Downloaded image 019/289
# Downloaded image 020/289
# Downloaded image 021/289
# Downloaded image 022/289
# Downloaded image 023/289
# Downloaded image 024/289
# Downloaded image 025/289
# Downloaded image 026/289
# Downloaded image 027/289
# Downloaded image 028/289
# Downloaded image 029/289
# Downloaded image 030/289
# Downloaded image 031/289
# Downloaded image 032/289
# Downloaded image 033/289
# Downloaded image 034/289
# Downloaded image 035/289
# Downloaded image 036/289
# Downloaded image 037/289
# Downloaded image 038/289
# Downloaded image 039/289
# Downloaded image 040/289
# Downloaded image 041/289
# Downloaded image 042/289
# Downloaded image 043/289
# Downloaded image 044/289
# Downloaded image 045/289
# Downloaded image 046/289
# Downloaded image 047/289
# Downloaded image 048/289
# Downloaded image 049/289
# Downloaded image 050/289
# Downloaded image 051/289
# Downloaded image 052/289
# Downloaded image 053/289
# Downloaded image 054/289
# Downloaded image 055/289
# Downloaded image 056/289
# Downloaded image 057/289
# Downloaded image 058/289
# Downloaded image 059/289
# Downloaded image 060/289
# Downloaded image 061/289
# Downloaded image 062/289
# Downloaded image 063/289
# Downloaded image 064/289
# Downloaded image 065/289
# Downloaded image 066/289
# Downloaded image 067/289
# Downloaded image 068/289
# Downloaded image 069/289
# Downloaded image 070/289
# Downloaded image 071/289
# Downloaded image 072/289
# Downloaded image 073/289
# Downloaded image 074/289
# Downloaded image 075/289
# Downloaded image 076/289
# Downloaded image 077/289
# Downloaded image 078/289
# Downloaded image 079/289
# Downloaded image 080/289
# Downloaded image 081/289
# Downloaded image 082/289
# Downloaded image 083/289
# Downloaded image 084/289
# Downloaded image 085/289
# Downloaded image 086/289
# Downloaded image 087/289
# Downloaded image 088/289
# Downloaded image 089/289
# Downloaded image 090/289
# Downloaded image 091/289
# Downloaded image 092/289
# Downloaded image 093/289
# Downloaded image 094/289
# Downloaded image 095/289
# Downloaded image 096/289
# Downloaded image 097/289
# Downloaded image 098/289
# Downloaded image 099/289
# Downloaded image 100/289
# Downloaded image 101/289
# Downloaded image 102/289
# Downloaded image 103/289
# Downloaded image 104/289
# Downloaded image 105/289
# Downloaded image 106/289
# Downloaded image 107/289
# Downloaded image 108/289
# Downloaded image 109/289
# Downloaded image 110/289
# Downloaded image 111/289
# Downloaded image 112/289
# Downloaded image 113/289
# Downloaded image 114/289
# Downloaded image 115/289
# Downloaded image 116/289
# Downloaded image 117/289
# Downloaded image 118/289
# Downloaded image 119/289
# Downloaded image 120/289
# Downloaded image 121/289
# Downloaded image 122/289
# Downloaded image 123/289
# Downloaded image 124/289
# Downloaded image 125/289
# Downloaded image 126/289
# Downloaded image 127/289
# Downloaded image 128/289
# Downloaded image 129/289
# Downloaded image 130/289
# Downloaded image 131/289
# Downloaded image 132/289
# Downloaded image 133/289
# Downloaded image 134/289
# Downloaded image 135/289
# Downloaded image 136/289
# Downloaded image 137/289
# Downloaded image 138/289
# Downloaded image 139/289
# Downloaded image 140/289
# Downloaded image 141/289
# Downloaded image 142/289
# Downloaded image 143/289
# Downloaded image 144/289
# Downloaded image 145/289
# Downloaded image 146/289
# Downloaded image 147/289
# Downloaded image 148/289
# Downloaded image 149/289
# Downloaded image 150/289
# Downloaded image 151/289
# Downloaded image 152/289
# Downloaded image 153/289
# Downloaded image 154/289
# Downloaded image 155/289
# Downloaded image 156/289
# Downloaded image 157/289
# Downloaded image 158/289
# Downloaded image 159/289
# Downloaded image 160/289
# Downloaded image 161/289
# Downloaded image 162/289
# Downloaded image 163/289
# Downloaded image 164/289
# Downloaded image 165/289
# Downloaded image 166/289
# Downloaded image 167/289
# Downloaded image 168/289
# Downloaded image 169/289
# Downloaded image 170/289
# Downloaded image 171/289
# Downloaded image 172/289
# Downloaded image 173/289
# Downloaded image 174/289
# Downloaded image 175/289
# Downloaded image 176/289
# Downloaded image 177/289
# Downloaded image 178/289
# Downloaded image 179/289
# Downloaded image 180/289
# Downloaded image 181/289
# Downloaded image 182/289
# Downloaded image 183/289
# Downloaded image 184/289
# Downloaded image 185/289
# Downloaded image 186/289
# Downloaded image 187/289
# Downloaded image 188/289
# Downloaded image 189/289
# Downloaded image 190/289
# Downloaded image 191/289
# Downloaded image 192/289
# Downloaded image 193/289
# Downloaded image 194/289
# Downloaded image 195/289
# Downloaded image 196/289
# Downloaded image 197/289
# Downloaded image 198/289
# Downloaded image 199/289
# Downloaded image 200/289
# Downloaded image 201/289
# Downloaded image 202/289
# Downloaded image 203/289
# Downloaded image 204/289
# Downloaded image 205/289
# Downloaded image 206/289
# Downloaded image 207/289
# Downloaded image 208/289
# Downloaded image 209/289
# Downloaded image 210/289
# Downloaded image 211/289
# Downloaded image 212/289
# Downloaded image 213/289
# Downloaded image 214/289
# Downloaded image 215/289
# Downloaded image 216/289
# Downloaded image 217/289
# Downloaded image 218/289
# Downloaded image 219/289
# Downloaded image 220/289
# Downloaded image 221/289
# Downloaded image 222/289
# Downloaded image 223/289
# Downloaded image 224/289
# Downloaded image 225/289
# Downloaded image 226/289
# Downloaded image 227/289
# Downloaded image 228/289
# Downloaded image 229/289
# Downloaded image 230/289
# Downloaded image 231/289
# Downloaded image 232/289
# Downloaded image 233/289
# Downloaded image 234/289
# Downloaded image 235/289
# Downloaded image 236/289
# Downloaded image 237/289
# Downloaded image 238/289
# Downloaded image 239/289
# Downloaded image 240/289
# Downloaded image 241/289
# Downloaded image 242/289
# Downloaded image 243/289
# Downloaded image 244/289
# Downloaded image 245/289
# Downloaded image 246/289
# Downloaded image 247/289
# Downloaded image 248/289
# Downloaded image 249/289
# Downloaded image 250/289
# Downloaded image 251/289
# Downloaded image 252/289
# Downloaded image 253/289
# Downloaded image 254/289
# Downloaded image 255/289
# Downloaded image 256/289
# Downloaded image 257/289
# Downloaded image 258/289
# Downloaded image 259/289
# Downloaded image 260/289
# Downloaded image 261/289
# Downloaded image 262/289
# Downloaded image 263/289
# Downloaded image 264/289
# Downloaded image 265/289
# Downloaded image 266/289
# Downloaded image 267/289
# Downloaded image 268/289
# Downloaded image 269/289
# Downloaded image 270/289
# Downloaded image 271/289
# Downloaded image 272/289
# Downloaded image 273/289
# Downloaded image 274/289
# Downloaded image 275/289
# Downloaded image 276/289
# Downloaded image 277/289
# Downloaded image 278/289
# Downloaded image 279/289
# Downloaded image 280/289
# Downloaded image 281/289
# Downloaded image 282/289
# Downloaded image 283/289
# Downloaded image 284/289
# Downloaded image 285/289
# Downloaded image 286/289
# Downloaded image 287/289
# Downloaded image 288/289
# Downloaded image 289/289
# Saving GeoTIFF. Please wait...
# Image saved to Data/Zoom17/TRY/0/field.tif
# Image has been split into chunks correctly.

# %% [markdown]
# # SAVE PREDICTIONS IN CSV

# %%
conf_thresholds = {
    'Dry': 0.75,
    'Wet': 0.6
}

class_names = ['Dry', 'Wet']


class_abbreviations = {'Dry': 'D', 'Wet': 'W'}

# %% [raw]
# Load the model

# %%
my_new_model = YOLO(model_path)

# %% [raw]
# Function to calculate entropy

# %%
def get_entropy(img, mask):
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY).astype(np.float32)  # Convert to grayscale
    mask[mask > 0] = 1  # Ensure mask is binary
    if mask.shape[:2] != img_gray.shape:
        print("Mask shape does not match image shape")
        return 0

    # Normalize the grayscale image to [0, 1]
    img_gray = (img_gray - img_gray.min()) / (img_gray.max() - img_gray.min())

    # Convert to uint8 after normalization
    img_gray = img_as_ubyte(img_gray)

    ent = entropy(img_gray.copy(), disk(5), mask=mask)
    ent = ent[ent > 5.2]
    if np.sum(mask) > 0:
        ent = np.sum(ent) / np.sum(mask)  # Average entropy based on the mask area
    else:
        ent = 0
    return ent

# %%
def process_image(image_path, conf_thresholds):
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to load image {image_path}")
        return None, None, None, None, None

    results = my_new_model.predict(img)

    polygons = []
    pred_classes = []
    conf_scores = []
    entropies = []

    if results[0].masks is not None:
        for i, (polygon, cls, conf) in enumerate(zip(results[0].masks.xy, results[0].boxes.cls.cpu().numpy(), results[0].boxes.conf.cpu().numpy())):
            class_name = class_names[int(cls)]
            if conf >= conf_thresholds[class_name]:
                polygons.append(polygon)
                pred_classes.append(class_name)
                conf_scores.append(conf)

                if class_name == 'Wet':  # Only compute entropy for Wet class
                    predicted_mask = results[0].masks.data.cpu().numpy()[i].astype(np.uint8)  # Convert to uint8
                    entropy_value = get_entropy(img, predicted_mask)  # Calculate entropy for the masked region
                    entropies.append(entropy_value)
                    print(f"Entropy for {class_name}: {entropy_value:.2f}")
                else:
                    entropies.append(None)  # Skip entropy calculation for Dry class

    return image_path, len(polygons), polygons, pred_classes, conf_scores, entropies


def extract_xtile_ytile(image_path):
    try:
        basename = os.path.basename(image_path)
        parts = basename.split('_')
        if len(parts) >= 4:
            # Handle both numeric tile numbers and coordinate values
            if '.' in parts[2]:  # It's a coordinate
                lon = float(parts[2])
                lat = float(parts[3].split('.')[0])
                zoom = int(parts[1])
                xtile = int(lon_to_pixel_x(lon, zoom) / 256)
                ytile = int(lat_to_pixel_y(lat, zoom) / 256)
            else:  # It's tile numbers
                xtile = int(parts[2])
                ytile = int(parts[3].split('.')[0])
            return xtile, ytile
        else:
            raise ValueError("Filename does not contain valid tile coordinates")
    except Exception as e:
        raise ValueError(f"Filename {image_path} does not contain valid tile coordinates: {e}")
def tile_corners_to_latlon(xtile, ytile, zoom):
    n = 2.0 ** zoom
    lon_deg = xtile / n * 360.0 - 180.0
    lat_rad_nw = math.atan(math.sinh(math.pi * (1 - 2 * (ytile / n))))
    lat_deg_nw = math.degrees(lat_rad_nw)

    lat_rad_se = math.atan(math.sinh(math.pi * (1 - 2 * ((ytile + 1) / n))))
    lat_deg_se = math.degrees(lat_rad_se)

    lat_deg_nw = max(min(lat_deg_nw, 85.0511), -85.0511)
    lat_deg_se = max(min(lat_deg_se, 85.0511), -85.0511)

    top_left = (lat_deg_nw, lon_deg)
    top_right = (lat_deg_nw, lon_deg + (360.0 / n))
    bottom_right = (lat_deg_se, lon_deg + (360.0 / n))
    bottom_left = (lat_deg_se, lon_deg)

    return top_left, top_right, bottom_left, bottom_right

def calculate_tile_center(top_left, top_right, bottom_left, bottom_right):
    center_lat = (top_left[0] + bottom_left[0]) / 2
    center_lon = (top_left[1] + top_right[1]) / 2
    return (center_lat, center_lon)

# %% [raw]
# Predictions

# %%
# Find all image tiles
image_files = []
for subfolder in sorted(os.listdir(image_dir)):  
    subfolder_path = os.path.join(image_dir, subfolder)
    if os.path.isdir(subfolder_path):
        chunk_path = os.path.join(subfolder_path, "chunks")
        if os.path.isdir(chunk_path):
            for file in os.listdir(chunk_path):
                if file.endswith(".tif"):
                    image_files.append(os.path.join(chunk_path, file))

print(f"Found {len(image_files)} images for processing.")
# Out:
# Found 289 images for processing.

# %%
max_vertices = 0

# To store processed data from process_image
image_data = []

# First Pass: Find max vertices in polygons and store image data
for image_path in image_files:
    _, _, polygons, pred_classes, conf_scores, entropies = process_image(image_path, conf_thresholds)
    if polygons:
        max_vertices = max(max_vertices, max(len(polygon) for polygon in polygons))
    image_data.append({
        'image_path': image_path,
        'polygons': polygons,
        'pred_classes': pred_classes,
        'entropies': entropies
    })

# Create dynamic column headers for X/Y coordinates
coordinate_headers = []
for i in range(1, max_vertices + 1):
    coordinate_headers.append(f"X_{i}")
    coordinate_headers.append(f"Y_{i}")

# Full header row
header = ["Image Path", "Predicted Class", "Center Latitude", "Center Longitude",
          "Top Left Latitude", "Top Left Longitude", "Top Right Latitude", "Top Right Longitude",
          "Bottom Left Latitude", "Bottom Left Longitude", "Bottom Right Latitude", "Bottom Right Longitude"] + coordinate_headers

# Process and save to CSV
start_time = time.time()

with open(csv_file, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(header)  # Write dynamic header row

    for data in image_data:
        image_path = data['image_path']
        polygons = data['polygons']
        pred_classes = data['pred_classes']
        entropies = data['entropies']

        if image_path is None:
            continue

        xtile, ytile = extract_xtile_ytile(image_path)
        top_left, top_right, bottom_left, bottom_right = tile_corners_to_latlon(xtile, ytile, zoom_level)
        latitude, longitude = calculate_tile_center(top_left, top_right, bottom_left, bottom_right)

        for pred_class, polygon, entropy_value in zip(pred_classes, polygons, entropies):
            if entropy_value is None or entropy_value > entropy_threshold:
                print(f"Skipped {pred_class} due to high entropy: {entropy_value if entropy_value is not None else 'None'}")
                continue

            row = [image_path, pred_class, latitude, longitude, top_left[0], top_left[1],
                   top_right[0], top_right[1], bottom_left[0], bottom_left[1], bottom_right[0], bottom_right[1]]

            # Flatten polygon coordinates while ensuring it matches max_vertices
            flat_polygon = [coord for point in polygon for coord in point]
            flat_polygon += [None] * (2 * max_vertices - len(flat_polygon))  # Fill missing values with None

            row.extend(flat_polygon)
            csvwriter.writerow(row)

end_time = time.time()

print(f"CSV file '{csv_file}' saved successfully.")
print(f"Time taken: {end_time - start_time:.2f} seconds.")
# Out:
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.8ms
# Speed: 0.5ms preprocess, 9.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.4ms preprocess, 9.0ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 10.2ms
# Speed: 0.4ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.9ms
# Speed: 0.6ms preprocess, 10.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.5ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.9ms
# Speed: 0.5ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 10.7ms
# Speed: 0.5ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.1ms
# Speed: 0.4ms preprocess, 10.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.4ms
# Speed: 0.5ms preprocess, 10.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.3ms
# Speed: 0.5ms preprocess, 10.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.4ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.5ms preprocess, 9.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.4ms preprocess, 9.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.66
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.5ms
# Speed: 0.6ms preprocess, 9.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.6ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.6ms
# Speed: 0.6ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.6ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.6ms
# Speed: 0.6ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.85
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.6ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.5ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.5ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 9.2ms
# Speed: 0.4ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.5ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.4ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.5ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 13.3ms
# Speed: 0.5ms preprocess, 13.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 2 Wets, 13.8ms
# Speed: 0.6ms preprocess, 13.8ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.45
#
# 0: 256x256 (no detections), 10.1ms
# Speed: 0.5ms preprocess, 10.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.4ms preprocess, 9.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.4ms preprocess, 8.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.3ms
# Speed: 0.3ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.0ms
# Speed: 0.4ms preprocess, 10.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.4ms preprocess, 9.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.4ms
# Speed: 0.5ms preprocess, 9.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.0ms
# Speed: 0.4ms preprocess, 10.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 9.4ms
# Speed: 0.4ms preprocess, 9.4ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.8ms
# Speed: 0.4ms preprocess, 9.8ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.3ms
# Speed: 0.5ms preprocess, 9.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.2ms
# Speed: 0.7ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.4ms
# Speed: 0.5ms preprocess, 9.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 9.5ms
# Speed: 0.5ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.6ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.5ms
# Speed: 0.4ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.5ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.4ms preprocess, 9.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.9ms
# Speed: 0.6ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.51
#
# 0: 256x256 1 Dry, 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.5ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 12.0ms
# Speed: 0.3ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.4ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.3ms
# Speed: 0.5ms preprocess, 10.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.3ms
# Speed: 0.4ms preprocess, 9.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.8ms
# Speed: 0.6ms preprocess, 9.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.6ms preprocess, 9.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.4ms
# Speed: 0.5ms preprocess, 9.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.6ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.7ms
# Speed: 0.8ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.5ms
# Speed: 0.3ms preprocess, 9.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.6ms
# Speed: 0.4ms preprocess, 9.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.5ms preprocess, 8.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.3ms
# Speed: 0.4ms preprocess, 10.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.4ms
# Speed: 0.4ms preprocess, 9.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 1.2ms preprocess, 8.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.7ms
# Speed: 0.3ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 3.47
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.4ms preprocess, 8.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 2 Wets, 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.83
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.3ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.4ms preprocess, 9.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.3ms
# Speed: 0.4ms preprocess, 9.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.1ms
# Speed: 0.4ms preprocess, 9.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.5ms
# Speed: 0.4ms preprocess, 9.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 15.1ms
# Speed: 0.4ms preprocess, 15.1ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 13.2ms
# Speed: 0.7ms preprocess, 13.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 12.6ms
# Speed: 0.5ms preprocess, 12.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 1 Wet, 9.4ms
# Speed: 0.5ms preprocess, 9.4ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.9ms
# Speed: 0.3ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.1ms
# Speed: 0.5ms preprocess, 9.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.97
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.3ms
# Speed: 0.8ms preprocess, 9.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.5ms
# Speed: 0.4ms preprocess, 9.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.5ms
# Speed: 0.4ms preprocess, 9.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.4ms
# Speed: 0.3ms preprocess, 9.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.3ms
# Speed: 0.5ms preprocess, 9.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.7ms
# Speed: 0.3ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.90
#
# 0: 256x256 1 Wet, 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.60
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.3ms preprocess, 9.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.8ms
# Speed: 0.5ms preprocess, 9.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.4ms preprocess, 9.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.7ms
# Speed: 0.4ms preprocess, 10.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.2ms
# Speed: 0.6ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.3ms preprocess, 8.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.84
#
# 0: 256x256 1 Wet, 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.0ms
# Speed: 0.5ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.6ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.5ms
# Speed: 0.4ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.5ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.5ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.0ms
# Speed: 0.5ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.3ms preprocess, 9.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.6ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.4ms
# Speed: 0.3ms preprocess, 10.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 3.15
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.3ms preprocess, 9.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 2.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.4ms preprocess, 8.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.7ms
# Speed: 0.4ms preprocess, 9.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.5ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.7ms
# Speed: 0.5ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.8ms
# Speed: 0.3ms preprocess, 9.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 12.7ms
# Speed: 0.7ms preprocess, 12.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 10.7ms
# Speed: 0.7ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.2ms
# Speed: 0.4ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.4ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.4ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.4ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.0ms
# Speed: 0.4ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.54
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.4ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.4ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.4ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.91
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.6ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.0ms
# Speed: 0.5ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.5ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.1ms
# Speed: 0.5ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 8.3ms
# Speed: 0.5ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 3.45
#
# 0: 256x256 (no detections), 6.9ms
# Speed: 0.5ms preprocess, 6.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.5ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.5ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 6.4ms
# Speed: 0.4ms preprocess, 6.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 6.5ms
# Speed: 0.4ms preprocess, 6.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 6.5ms
# Speed: 0.4ms preprocess, 6.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 6.4ms
# Speed: 0.3ms preprocess, 6.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 6.5ms
# Speed: 0.3ms preprocess, 6.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 14.8ms
# Speed: 0.8ms preprocess, 14.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 14.4ms
# Speed: 0.7ms preprocess, 14.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# Skipped Wet due to high entropy: 2.658187544766383
# Skipped Wet due to high entropy: 2.8535733675079324
# Skipped Wet due to high entropy: 3.4677605766120694
# Skipped Wet due to high entropy: 2.895783039478012
# Skipped Wet due to high entropy: 2.5958001617364097
# Skipped Wet due to high entropy: 2.8386112865033457
# Skipped Wet due to high entropy: 3.149471398892842
# Skipped Wet due to high entropy: 2.5358150787042306
# Skipped Wet due to high entropy: 3.448417388884291
# CSV file 'CSV_Output/TRY.csv' saved successfully.
# Time taken: 0.00 seconds.

# %% [markdown]
# # Add Buffer to combine nearby predicted objects

# %%
EARTH_CIRCUMFERENCE_DEGREES = 360  # degrees

# %%
# Load the CSV file
df = pd.read_csv(csv_file)
df.rename(columns={'Predicted Class': 'Class'}, inplace=True)

# %%
# Extract the base name dynamically (e.g., "TRY" from "TRY.csv")
csv_basename = os.path.splitext(os.path.basename(csv_file))[0]

# %%
def pixel_to_geo(x, y, lat_top_left, lon_top_left, lat_bottom_right, lon_bottom_right, img_width, img_height):
    lon_range = lon_bottom_right - lon_top_left
    lat_range = lat_top_left - lat_bottom_right  # Ensure correct sign

    lon = lon_top_left + (x / img_width) * lon_range
    
    # Ensure latitude decreases as 'y' increases (accounting for top-left origin)
    lat = lat_top_left - (y / img_height) * lat_range

    return lon, lat


# Initialize an empty list for GeoJSON features
geojson_features = []

# Iterate through each row
for _, row in df.iterrows():
    lat_top_left = row['Top Left Latitude']
    lon_top_left = row['Top Left Longitude']
    lat_bottom_right = row['Bottom Right Latitude']
    lon_bottom_right = row['Bottom Right Longitude']

    tile_width, tile_height = 256, 256

    object_coords = []

    # Iterate over all possible coordinate columns dynamically
    i = 1
    while True:
        x_col = f'X_{i}'
        y_col = f'Y_{i}'

        if x_col not in row or y_col not in row:
            break  # Stop if columns don't exist

        x = row[x_col]
        y = row[y_col]

        if pd.notna(x) and pd.notna(y):
            lon, lat = pixel_to_geo(x, y, lat_top_left, lon_top_left, lat_bottom_right, lon_bottom_right, tile_width, tile_height)
            if np.isfinite(lon) and np.isfinite(lat):
                object_coords.append((lon, lat))
        else:
            break  # Stop when NaN values appear

        i += 1  # Move to the next set of coordinates

    # Ensure the polygon has at least 3 points before adding
    if len(object_coords) >= 3:
        object_coords.append(object_coords[0])  # Close the polygon
        polygon_geometry = Polygon(object_coords)
        feature = {
            "type": "Feature",
            "geometry": polygon_geometry,
            "properties": {
                "Class": row['Class']
            }
        }
        geojson_features.append(feature)

# Convert to GeoDataFrame
gdf_final = gpd.GeoDataFrame(
    [feature['properties'] for feature in geojson_features],
    geometry=[feature['geometry'] for feature in geojson_features],
    crs="EPSG:4326"
)

# Merge overlapping geometries


# Merge overlapping geometries
buffer_distance = 0.0005  
gdf_final['Buffered'] = gdf_final.geometry.buffer(buffer_distance)
combined_polygons = unary_union(gdf_final['Buffered'])
combined_polygons = combined_polygons.buffer(-buffer_distance)

# Convert back to GeoDataFrame
gdf_combined = gpd.GeoDataFrame(geometry=[combined_polygons], crs="EPSG:4326")

# Ensure the output folder exists
output_folder = 'Shapefile_Output'
os.makedirs(output_folder, exist_ok=True)

# Save the final shapefile in the 'Shapefile_Output' folder
shapefile_path = os.path.join(output_folder, f"{csv_basename}_COMBINED_GEOMETRY.shp")
gdf_combined.to_file(shapefile_path)

# Create the ZIP file in the 'Shapefile_Output' folder
zip_filename = os.path.join(output_folder, f"{csv_basename}_COMBINED_GEOMETRY.zip")
shapefile_files = glob.glob(os.path.join(output_folder, f"{csv_basename}_COMBINED_GEOMETRY.*"))  

# Exclude the .csv file from the list of files to be zipped
shapefile_files = [file for file in shapefile_files if not file.endswith('.csv')]

# Add the shapefile files to the zip archive
with zipfile.ZipFile(zip_filename, "w") as zipf:
    for file in shapefile_files:
        zipf.write(file, os.path.basename(file))

print(f"Created ZIP file: {zip_filename}")

# Delete the original shapefile files after zipping, but keep the .csv file
for file in shapefile_files:
    os.remove(file)
    print(f"Deleted: {file}")

print("All shapefile components have been deleted after zipping, except for the .csv file.")
# Out:
# Created ZIP file: Shapefile_Output/TRY_COMBINED_GEOMETRY.zip
# Deleted: Shapefile_Output/TRY_COMBINED_GEOMETRY.dbf
# Deleted: Shapefile_Output/TRY_COMBINED_GEOMETRY.prj
# Deleted: Shapefile_Output/TRY_COMBINED_GEOMETRY.cpg
# Deleted: Shapefile_Output/TRY_COMBINED_GEOMETRY.shx
# Deleted: Shapefile_Output/TRY_COMBINED_GEOMETRY.shp
# All shapefile components have been deleted after zipping, except for the .csv file.
# /tmp/ipykernel_387751/4198362238.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_final['Buffered'] = gdf_final.geometry.buffer(buffer_distance)
