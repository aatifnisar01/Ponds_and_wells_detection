# %% [markdown]
# # Necessary Steps

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#!pip install -U ultralytics

# %%
import json
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import shutil
from random import choice
import re
import csv
import zipfile
import pandas as pd
import glob
import math
import geopandas as gpd
from shapely.geometry import shape
from shapely.geometry import Polygon
from ultralytics import YOLO
from PIL import Image
import requests
import time
import os
from ultralytics import YOLO
from skimage.filters.rank import entropy
from skimage.morphology import disk
from skimage.util import img_as_ubyte
from shapely.geometry import box

# %%
cd /home/core-stack/Documents/Ponds
# Out:
# /home/core-stack/Documents/Ponds

# %%
pwd = os.getcwd()
pwd
# Out:
# '/home/core-stack/Documents/Ponds'

# %% [markdown]
# # Download Data for Inference

# %%
pwd

# %% [markdown]
# Get Bounding boxes automatically from GeoJSON instead of manually drawing on GEE

# %%
gdf = gpd.read_file("Koraput.geojson")

# %%
# Compute the bounding box
minx, miny, maxx, maxy = gdf.total_bounds

# Create a bounding box polygon
bounding_box = gpd.GeoDataFrame(geometry=[box(minx, miny, maxx, maxy)], crs=gdf.crs)

# Plot the geometry and the updated bounding box
fig, ax = plt.subplots(figsize=(10, 6))
gdf.plot(ax=ax, color="blue", alpha=0.5, edgecolor="black")
bounding_box.plot(ax=ax, edgecolor="red", facecolor="none", linewidth=2)

plt.show()

# %%
# Get the bounding box coordinates
minx, miny, maxx, maxy = gdf.total_bounds

# Define bounding box points
topLeft = [minx, maxy]
topRight = [maxx, maxy]
bottomRight = [maxx, miny]
bottomLeft = [minx, miny]

# Print the coordinates
print(f"topLeft = {topLeft}")
print(f"topRight = {topRight}")
print(f"bottomRight = {bottomRight}")
print(f"bottomLeft = {bottomLeft}")

# %% [markdown]
# NOT NEEDED ANYMORE - Give coordinated of the bounding box drawn on GEE

# %%
"""
#coords for the bounding box (boipariguda)
topLeft = [82.07347488402685,18.57110542069261]
topRight = [82.60081863402685,18.57110542069261]
bottomRight = [82.60081863402685,18.9572939770273]
bottomLeft = [82.07347488402685,18.9572939770273]
"""

# %% [markdown]
# Zoom Level and folder name, where the output (image tiles) will be saved

# %%
zoom_level = 17       # Zoom level
output_folder = "/content/drive/MyDrive/Pond/Data_Download/Final/Zoom17/Boipariguda"

# %%
def deg2num(lat_deg, lon_deg, zoom):
    lat_rad = math.radians(lat_deg)
    n = 2.0 ** zoom
    xtile = int((lon_deg + 180.0) / 360.0 * n)
    ytile = int((1.0 - math.log(math.tan(lat_rad) + (1 / math.cos(lat_rad))) / math.pi) / 2.0 * n)
    return (xtile, ytile)

def getCoords(zoomLevel):
    topleft = deg2num(topLeft[1], topLeft[0], zoomLevel)  # (c,b)
    topright = deg2num(topRight[1], topRight[0], zoomLevel)  # (a,b)
    bottomright = deg2num(bottomRight[1], bottomRight[0], zoomLevel)  # (a,d)
    bottomleft = deg2num(bottomLeft[1], bottomLeft[0], zoomLevel)  # (c,d)
    xmin = min(topleft[0], topright[0], bottomleft[0], bottomright[0])
    xmax = max(topleft[0], topright[0], bottomleft[0], bottomright[0])
    ymin = min(topleft[1], topright[1], bottomleft[1], bottomright[1])
    ymax = max(topleft[1], topright[1], bottomleft[1], bottomright[1])
    return (xmin, xmax, ymin, ymax)

def download_map_tiles(base_url, output_folder, zoom_level, scale):
    # Ensure output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Get start time
    start_time = time.time()

    # Iterate over each tile within the specified range
    xmin, xmax, ymin, ymax = getCoords(zoom_level)
    for x in range(xmin, xmax + 1):
        for y in range(ymin, ymax + 1):
            # Construct the URL for the current tile with scale=3 for 640x640
            tile_url = f"{base_url}&x={x}&y={y}&z={zoom_level}&scale={scale}"
            print(tile_url)
            try:
                # Send HTTP GET request to fetch the tile
                response = requests.get(tile_url)

                # Check if request was successful (status code 200)
                if response.status_code == 200:
                    # Save the tile image to a file in the output folder
                    filename = f"tile_{zoom_level}_{x}_{y}.png"
                    filepath = os.path.join(output_folder, filename)
                    with open(filepath, "wb") as f:
                        f.write(response.content)
                    print(f"Downloaded: {filename}")
                else:
                    print(f"Failed to download tile ({x}, {y}), HTTP status code: {response.status_code}")

            except Exception as e:
                print(f"Error downloading tile ({x}, {y}): {e}")

    # Get end time
    end_time = time.time()

    # Print the total execution time
    print(f"Total time taken: {end_time - start_time} seconds")

# %%
base_url = "https://mt1.google.com/vt/lyrs=s"
scale = 1           # scale of 1 = 256*256 dimensional image

if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Created the folder: {output_folder}")
else:
    print(f"The folder already exists: {output_folder}")

# %%
download_map_tiles(base_url, output_folder, zoom_level, scale)

# %% [markdown]
# # SAVE PREDICTIONS IN CSV

# %%
pwd
# Out:
# '/home/core-stack/Documents/Ponds'

# %% [markdown]
# Initialize model and parameters

# %%
model_path = "Ponds_best.pt"

image_dir = "Masalia_full"

csv_file = "Masalia_full.csv"

zoom = 17

entropy_threshold = 2.5

# %%
conf_thresholds = {
    'Dry': 0.75,
    'Wet': 0.6
}

class_names = ['Dry', 'Wet']


class_abbreviations = {'Dry': 'D', 'Wet': 'W'}

# %% [markdown]
# Function to calculate entropy

# %%
def get_entropy(img, mask):
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY).astype(np.float32)  # Convert to grayscale
    mask[mask > 0] = 1  # Ensure mask is binary
    if mask.shape[:2] != img_gray.shape:
        print("Mask shape does not match image shape")
        return 0

    # Normalize the grayscale image to [0, 1]
    img_gray = (img_gray - img_gray.min()) / (img_gray.max() - img_gray.min())

    # Convert to uint8 after normalization
    img_gray = img_as_ubyte(img_gray)

    ent = entropy(img_gray.copy(), disk(5), mask=mask)
    ent = ent[ent > 5.2]
    if np.sum(mask) > 0:
        ent = np.sum(ent) / np.sum(mask)  # Average entropy based on the mask area
    else:
        ent = 0
    return ent

# %% [markdown]
# Load the model

# %%
my_new_model = YOLO(model_path)

# %% [markdown]
# Functions to save segmented/detected object in a CSV

# %%
def process_image(image_path, conf_thresholds):
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to load image {image_path}")
        return None, None, None, None, None

    results = my_new_model.predict(img)

    polygons = []
    pred_classes = []
    conf_scores = []
    entropies = []

    if results[0].masks is not None:
        for i, (polygon, cls, conf) in enumerate(zip(results[0].masks.xy, results[0].boxes.cls.cpu().numpy(), results[0].boxes.conf.cpu().numpy())):
            class_name = class_names[int(cls)]
            if conf >= conf_thresholds[class_name]:
                polygons.append(polygon)
                pred_classes.append(class_name)
                conf_scores.append(conf)

                if class_name == 'Wet':  # Only compute entropy for Wet class
                    predicted_mask = results[0].masks.data.cpu().numpy()[i].astype(np.uint8)  # Convert to uint8
                    entropy_value = get_entropy(img, predicted_mask)  # Calculate entropy for the masked region
                    entropies.append(entropy_value)
                    print(f"Entropy for {class_name}: {entropy_value:.2f}")
                else:
                    entropies.append(None)  # Skip entropy calculation for Dry class

    return image_path, len(polygons), polygons, pred_classes, conf_scores, entropies


def extract_xtile_ytile(image_path):
    try:
        basename = os.path.basename(image_path)
        parts = basename.split('_')
        if len(parts) >= 4:
            xtile = int(parts[2])
            ytile = int(parts[3].split('.')[0].split()[0])
            return xtile, ytile
        else:
            raise ValueError("Filename does not contain valid tile coordinates")
    except Exception as e:
        raise ValueError(f"Filename {image_path} does not contain valid tile coordinates: {e}")

def tile_corners_to_latlon(xtile, ytile, zoom):
    n = 2.0 ** zoom
    lon_deg = xtile / n * 360.0 - 180.0
    lat_rad_nw = math.atan(math.sinh(math.pi * (1 - 2 * (ytile / n))))
    lat_deg_nw = math.degrees(lat_rad_nw)

    lat_rad_se = math.atan(math.sinh(math.pi * (1 - 2 * ((ytile + 1) / n))))
    lat_deg_se = math.degrees(lat_rad_se)

    lat_deg_nw = max(min(lat_deg_nw, 85.0511), -85.0511)
    lat_deg_se = max(min(lat_deg_se, 85.0511), -85.0511)

    top_left = (lat_deg_nw, lon_deg)
    top_right = (lat_deg_nw, lon_deg + (360.0 / n))
    bottom_right = (lat_deg_se, lon_deg + (360.0 / n))
    bottom_left = (lat_deg_se, lon_deg)

    return top_left, top_right, bottom_left, bottom_right

def calculate_tile_center(top_left, top_right, bottom_left, bottom_right):
    center_lat = (top_left[0] + bottom_left[0]) / 2
    center_lon = (top_left[1] + top_right[1]) / 2
    return (center_lat, center_lon)

def visualize_polygons(image_path, polygons, pred_classes, conf_scores):
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to load image {image_path}")
        return

    if len(polygons) == 0:
        print(f"No predictions for image {image_path}, not saving.")
        return

    for i, polygon in enumerate(polygons):
        polygon = np.array(polygon, dtype=np.int32)
        polygon = polygon.reshape((-1, 1, 2))
        cv2.polylines(img, [polygon], isClosed=True, color=(0, 255, 0), thickness=2)

        # Calculate the centroid of the polygon for placing the text
        M = cv2.moments(polygon)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
        else:
            cX, cY = polygon[0][0]

        # Put class abbreviation and confidence score text on the image
        class_abbr = class_abbreviations[pred_classes[i]]
        conf_text = f"{class_abbr}: {conf_scores[i]:.2f}"
        cv2.putText(img, conf_text, (cX, cY), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

    output_path = os.path.join(annotated_images_dir, os.path.basename(image_path))
    cv2.imwrite(output_path, img)
    print(f"Annotated image saved to {output_path}")

# %% [markdown]
# Predictions

# %%
image_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if os.path.isfile(os.path.join(image_dir, f))]

# %%
len(image_files)
# Out:
# 11311

# %%
max_vertices = 0
image_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if os.path.isfile(os.path.join(image_dir, f))]

# First Pass: Find max vertices in polygons
for image_path in image_files:
    _, _, polygons, _, _, _ = process_image(image_path, conf_thresholds)
    if polygons:
        max_vertices = max(max_vertices, max(len(polygon) for polygon in polygons))

# Create dynamic column headers for X/Y coordinates
coordinate_headers = []
for i in range(1, max_vertices + 1):
    coordinate_headers.append(f"X_{i}")
    coordinate_headers.append(f"Y_{i}")

# Full header row
header = ["Image Path", "Predicted Class", "Center Latitude", "Center Longitude",
          "Top Left Latitude", "Top Left Longitude", "Top Right Latitude", "Top Right Longitude",
          "Bottom Left Latitude", "Bottom Left Longitude", "Bottom Right Latitude", "Bottom Right Longitude"] + coordinate_headers

# Process and save to CSV
start_time = time.time()

with open(csv_file, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(header)  # Write dynamic header row

    for image_path in image_files:
        try:
            image_path, num_polygons, polygons, pred_classes, conf_scores, entropies = process_image(image_path, conf_thresholds)
            if image_path is None:
                continue

            xtile, ytile = extract_xtile_ytile(image_path)
            top_left, top_right, bottom_left, bottom_right = tile_corners_to_latlon(xtile, ytile, zoom)
            latitude, longitude = calculate_tile_center(top_left, top_right, bottom_left, bottom_right)

            for pred_class, polygon, entropy_value in zip(pred_classes, polygons, entropies):
                if entropy_value is None or entropy_value > entropy_threshold:
                    print(f"Skipped {pred_class} due to high entropy: {entropy_value if entropy_value is not None else 'None'}")
                    continue

                row = [image_path, pred_class, latitude, longitude, top_left[0], top_left[1],
                       top_right[0], top_right[1], bottom_left[0], bottom_left[1], bottom_right[0], bottom_right[1]]

                # Flatten polygon coordinates while ensuring it matches max_vertices
                flat_polygon = [coord for point in polygon for coord in point]
                flat_polygon += [None] * (2 * max_vertices - len(flat_polygon))  # Fill missing values with None

                row.extend(flat_polygon)
                csvwriter.writerow(row)

        except ValueError as e:
            print(f"ValueError: {e}")
            continue

end_time = time.time()

print(f"CSV file '{csv_file}' saved successfully.")
print(f"Time taken: {end_time - start_time:.2f} seconds.")
# Out:
# 0: 256x256 (no detections), 8.7ms
# Speed: 3.9ms preprocess, 8.7ms inference, 17.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 87.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.6ms
# Speed: 0.4ms preprocess, 10.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.6ms
# Speed: 0.5ms preprocess, 9.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.1ms
# Speed: 0.4ms preprocess, 9.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.6ms
# Speed: 0.6ms preprocess, 10.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 2 Wets, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.38
# Entropy for Wet: 1.14
#
# 0: 256x256 (no detections), 10.2ms
# Speed: 0.5ms preprocess, 10.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.9ms
# Speed: 0.4ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 11.0ms
# Speed: 0.3ms preprocess, 11.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.0ms
# Speed: 0.5ms preprocess, 10.0ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.9ms
# Speed: 0.5ms preprocess, 9.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 9.0ms
# Speed: 0.4ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.97
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.6ms
# Speed: 0.8ms preprocess, 10.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.8ms
# Speed: 0.4ms preprocess, 9.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.3ms
# Speed: 0.6ms preprocess, 10.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.4ms preprocess, 9.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.9ms
# Speed: 0.5ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.1ms
# Speed: 0.4ms preprocess, 9.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.8ms
# Speed: 0.3ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.7ms
# Speed: 0.3ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.91
#
# 0: 256x256 2 Wets, 9.0ms
# Speed: 0.4ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.99
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.7ms
# Speed: 0.3ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.7ms
# Speed: 0.4ms preprocess, 9.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.7ms
# Speed: 0.4ms preprocess, 9.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.3ms
# Speed: 0.5ms preprocess, 10.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 10.1ms
# Speed: 0.5ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 10.2ms
# Speed: 0.4ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.5ms
# Speed: 0.5ms preprocess, 9.5ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.8ms
# Speed: 0.7ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.3ms preprocess, 9.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 1 Wet, 9.7ms
# Speed: 0.6ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 12.5ms
# Speed: 0.5ms preprocess, 12.5ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 12.6ms
# Speed: 0.4ms preprocess, 12.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 9.2ms
# Speed: 0.5ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.53
#
# 0: 256x256 1 Dry, 10.0ms
# Speed: 0.6ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.3ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.4ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.6ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.7ms
# Speed: 0.4ms preprocess, 9.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 10.9ms
# Speed: 0.5ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.6ms
# Speed: 0.3ms preprocess, 9.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.7ms
# Speed: 0.4ms preprocess, 9.7ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.9ms
# Speed: 0.5ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.1ms
# Speed: 0.4ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.6ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.4ms preprocess, 9.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.2ms
# Speed: 0.4ms preprocess, 10.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.5ms
# Speed: 0.6ms preprocess, 9.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.7ms
# Speed: 0.5ms preprocess, 10.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.4ms
# Speed: 0.5ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.53
#
# 0: 256x256 1 Wet, 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.71
#
# 0: 256x256 1 Wet, 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.3ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.36
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.3ms preprocess, 9.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.97
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.20
#
# 0: 256x256 3 Wets, 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.82
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.4ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.5ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.57
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.8ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.3ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.3ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.8ms
# Speed: 0.5ms preprocess, 9.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 9.9ms
# Speed: 0.5ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 8.6ms
# Speed: 0.6ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.1ms
# Speed: 0.3ms preprocess, 9.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 3 Wets, 8.6ms
# Speed: 0.5ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.01
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.4ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.2ms
# Speed: 0.3ms preprocess, 10.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.3ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.3ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.4ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.4ms
# Speed: 0.7ms preprocess, 9.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.4ms
# Speed: 0.6ms preprocess, 9.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.6ms
# Speed: 0.5ms preprocess, 9.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 10.2ms
# Speed: 0.7ms preprocess, 10.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.6ms
# Speed: 0.4ms preprocess, 10.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 9.4ms
# Speed: 0.4ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.45
#
# 0: 256x256 1 Wet, 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.64
#
# 0: 256x256 1 Wet, 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 3 Wets, 8.8ms
# Speed: 0.3ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 9.1ms
# Speed: 0.3ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.5ms
# Speed: 0.4ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.8ms
# Speed: 0.5ms preprocess, 9.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 2.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.0ms
# Speed: 0.4ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.1ms
# Speed: 0.5ms preprocess, 10.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.5ms
# Speed: 0.4ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 10.0ms
# Speed: 0.3ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.8ms
# Speed: 0.5ms preprocess, 9.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.7ms
# Speed: 0.4ms preprocess, 9.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 9.4ms
# Speed: 0.4ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.17
#
# 0: 256x256 1 Dry, 1 Wet, 9.0ms
# Speed: 0.4ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.6ms
# Speed: 0.4ms preprocess, 9.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.8ms
# Speed: 0.4ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.1ms
# Speed: 0.4ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 9.7ms
# Speed: 0.3ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 9.1ms
# Speed: 0.4ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.3ms
# Speed: 0.5ms preprocess, 9.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.2ms
# Speed: 0.4ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 3 Drys, 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 8.5ms
# Speed: 0.4ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.07
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.3ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.4ms
# Speed: 0.6ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.1ms
# Speed: 0.6ms preprocess, 9.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.1ms
# Speed: 0.4ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.8ms
# Speed: 0.3ms preprocess, 9.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.4ms
# Speed: 0.5ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 0.74
#
# 0: 256x256 1 Dry, 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.3ms
# Speed: 0.3ms preprocess, 9.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 10.2ms
# Speed: 0.5ms preprocess, 10.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.15
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.6ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.5ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.1ms
# Speed: 0.5ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.72
#
# 0: 256x256 1 Wet, 8.5ms
# Speed: 0.5ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 10.3ms
# Speed: 0.7ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.2ms
# Speed: 0.5ms preprocess, 10.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 10.0ms
# Speed: 0.4ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 9.8ms
# Speed: 0.4ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.4ms
# Speed: 0.4ms preprocess, 9.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.3ms
# Speed: 0.3ms preprocess, 9.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.7ms
# Speed: 0.3ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 9.2ms
# Speed: 0.4ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.4ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.5ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 0.88
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.6ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.3ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.3ms
# Speed: 0.4ms preprocess, 9.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.3ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.9ms
# Speed: 0.3ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.5ms
# Speed: 0.4ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.1ms
# Speed: 0.4ms preprocess, 9.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.3ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.90
#
# 0: 256x256 2 Drys, 9.2ms
# Speed: 0.5ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 3 Drys, 1 Wet, 8.5ms
# Speed: 0.4ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 9.6ms
# Speed: 0.4ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 9.0ms
# Speed: 0.3ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.53
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.5ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.8ms
# Speed: 0.5ms preprocess, 9.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.78
# Entropy for Wet: 1.87
#
# 0: 256x256 1 Dry, 8.9ms
# Speed: 0.3ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.7ms
# Speed: 0.4ms preprocess, 9.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.6ms
# Speed: 0.3ms preprocess, 9.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.1ms
# Speed: 0.3ms preprocess, 9.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.74
#
# 0: 256x256 (no detections), 10.4ms
# Speed: 0.3ms preprocess, 10.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.1ms
# Speed: 0.4ms preprocess, 9.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.5ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.76
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 3 Wets, 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.5ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.8ms
# Speed: 0.6ms preprocess, 9.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.8ms
# Speed: 0.3ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.32
# Entropy for Wet: 1.67
#
# 0: 256x256 (no detections), 8.9ms
# Speed: 0.4ms preprocess, 8.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 9.2ms
# Speed: 0.5ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.7ms
# Speed: 0.5ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.21
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 3.33
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 9.3ms
# Speed: 0.4ms preprocess, 9.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.16
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 7.7ms
# Speed: 0.4ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 7.7ms
# Speed: 0.4ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.6ms
# Speed: 0.3ms preprocess, 7.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 9.5ms
# Speed: 0.3ms preprocess, 9.5ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 13.7ms
# Speed: 0.5ms preprocess, 13.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.7ms
# Speed: 0.4ms preprocess, 10.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.5ms
# Speed: 0.4ms preprocess, 9.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 10.0ms
# Speed: 0.4ms preprocess, 10.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.9ms
# Speed: 0.3ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.3ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.49
#
# 0: 256x256 1 Dry, 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.6ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.22
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.4ms preprocess, 8.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 3 Wets, 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.79
#
# 0: 256x256 (no detections), 9.0ms
# Speed: 0.3ms preprocess, 9.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.0ms
# Speed: 0.6ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.22
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.5ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.6ms
# Speed: 0.4ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.6ms
# Speed: 0.3ms preprocess, 7.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.35
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.7ms
# Speed: 0.4ms preprocess, 7.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.6ms
# Speed: 0.3ms preprocess, 7.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 7.4ms
# Speed: 0.3ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 3 Wets, 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.66
# Entropy for Wet: 2.27
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.6ms
# Speed: 0.4ms preprocess, 7.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.88
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.9ms
# Speed: 0.9ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.6ms
# Speed: 0.3ms preprocess, 7.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.5ms
# Speed: 0.3ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.65
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.6ms
# Speed: 0.3ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.08
#
# 0: 256x256 1 Dry, 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 7.7ms
# Speed: 0.4ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.4ms
# Speed: 0.3ms preprocess, 7.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.4ms
# Speed: 0.3ms preprocess, 7.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.3ms preprocess, 9.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 12.1ms
# Speed: 0.3ms preprocess, 12.1ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 14.0ms
# Speed: 0.5ms preprocess, 14.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 11.1ms
# Speed: 0.5ms preprocess, 11.1ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.36
#
# 0: 256x256 2 Wets, 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.5ms
# Speed: 0.3ms preprocess, 7.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.5ms
# Speed: 0.4ms preprocess, 7.5ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.4ms
# Speed: 0.2ms preprocess, 7.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.6ms
# Speed: 0.4ms preprocess, 7.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.5ms
# ...
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 9.2ms
# Speed: 0.3ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 3 Wets, 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.54
#
# 0: 256x256 1 Dry, 9.1ms
# Speed: 0.7ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.62
# Skipped Wet due to high entropy: 2.620315656428967
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.5ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.6ms
# Speed: 0.3ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.3ms
# Speed: 0.5ms preprocess, 9.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.7ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.4ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.15
#
# 0: 256x256 2 Wets, 9.3ms
# Speed: 0.3ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.59
# Skipped Wet due to high entropy: 2.5908908567109057
#
# 0: 256x256 1 Wet, 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.0ms
# Speed: 0.7ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.6ms
# Speed: 0.3ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.4ms
# Speed: 0.3ms preprocess, 9.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 2.7ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.4ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 9.2ms
# Speed: 0.4ms preprocess, 9.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 7.6ms
# Speed: 0.3ms preprocess, 7.6ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.6ms
# Speed: 0.3ms preprocess, 7.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.6ms
# Speed: 0.3ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.6ms
# Speed: 0.3ms preprocess, 7.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Drys, 2 Wets, 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 3 Wets, 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.15
#
# 0: 256x256 (no detections), 8.8ms
# Speed: 0.4ms preprocess, 8.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.9ms
# Speed: 0.3ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 0.76
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.5ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.7ms
# Speed: 0.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 3.03
# Skipped Wet due to high entropy: 3.0306489735918016
#
# 0: 256x256 (no detections), 8.4ms
# Speed: 0.8ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.5ms
# Speed: 0.3ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 2.16
#
# 0: 256x256 1 Dry, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 7.8ms
# Speed: 0.3ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 2 Wets, 8.5ms
# Speed: 0.2ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 1.97
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 2 Wets, 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.6ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 3 Wets, 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 1 Wet, 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 9.5ms
# Speed: 0.4ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.3ms
# Speed: 0.4ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.6ms
# Speed: 0.4ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.3ms
# Speed: 0.3ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.9ms
# Speed: 0.3ms preprocess, 7.9ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.7ms
# Speed: 0.3ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 7.8ms
# Speed: 0.4ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.4ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.3ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.3ms preprocess, 8.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Wet, 8.2ms
# Speed: 0.3ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# Entropy for Wet: 3.08
# Skipped Wet due to high entropy: 3.0812122144062033
#
# 0: 256x256 (no detections), 8.0ms
# Speed: 0.6ms preprocess, 8.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.1ms
# Speed: 0.4ms preprocess, 8.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Dry, 7.9ms
# Speed: 0.4ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Pred Name Columns Changes

# %% [markdown]
# # Convert to Geometry

# %%
pwd
# Out:
# '/home/core-stack/Documents/Ponds'

# %%
ZOOM_LEVEL = 17
EARTH_CIRCUMFERENCE_DEGREES = 360  # degrees

# %%
# Load the CSV file
csv_filepath = 'Masalia_full.csv'
df = pd.read_csv(csv_filepath)

df.rename(columns={'Predicted Class': 'Class'}, inplace=True)

# %%
# Extract the base name dynamically (e.g., "TRY" from "TRY.csv")
csv_basename = os.path.splitext(os.path.basename(csv_filepath))[0]
csv_basename
# Out:
# 'Masalia_full'

# %%
def degrees_per_pixel(zoom):
    total_pixels = 256 * (2 ** zoom)
    degrees_per_pixel = EARTH_CIRCUMFERENCE_DEGREES / total_pixels
    return degrees_per_pixel

def pixel_to_geo(x, y, lat_top_left, lon_top_left, lat_bottom_right, lon_bottom_right, img_width, img_height):
    lon_range = lon_bottom_right - lon_top_left
    lat_range = lat_top_left - lat_bottom_right  # Note: latitude decreases as you go south
    lon = lon_top_left + (x / img_width) * lon_range
    lat = lat_top_left - (y / img_height) * lat_range  # y increases downward in image coordinates
    return lon, lat

# Initialize an empty list to store GeoJSON features
geojson_features = []

# Iterate over each row in the dataframe
for index, row in df.iterrows():
    # Extract bounding coordinates of the image tile
    lat_top_left = row['Top Left Latitude']
    lon_top_left = row['Top Left Longitude']
    lat_bottom_right = row['Bottom Right Latitude']
    lon_bottom_right = row['Bottom Right Longitude']

    tile_width, tile_height = 256, 256

    # Initialize an empty list to store coordinates of the current object
    object_coords = []

    for i in range(1, 8759):  # Adjust this range according to your data
        x_col = f'X_{i}'
        y_col = f'Y_{i}'
        if x_col in row and y_col in row:
            x = row[x_col]
            y = row[y_col]
            if pd.notna(x) and pd.notna(y):
                # Convert pixel coordinates to geographic coordinates
                lon, lat = pixel_to_geo(x, y, lat_top_left, lon_top_left, lat_bottom_right, lon_bottom_right, tile_width, tile_height)
                if np.isfinite(lon) and np.isfinite(lat):
                    object_coords.append((lon, lat))
            if pd.isna(x) or pd.isna(y) or i == 8758:  # Check if it's the end of the coordinates
                if object_coords:  # Close the current shape if it has points
                    object_coords.append(object_coords[0])  # Close the polygon
                    polygon_geometry = Polygon(object_coords)
                    feature = {
                        "type": "Feature",
                        "geometry": polygon_geometry,
                        "properties": {
                            "Class": row['Class']
                        }
                    }
                    geojson_features.append(feature)
                object_coords = []

    # After the loop, check if there are any remaining coordinates to close the last polygon
    if object_coords:
        object_coords.append(object_coords[0])  # Close the polygon
        polygon_geometry = Polygon(object_coords)
        feature = {
            "type": "Feature",
            "geometry": polygon_geometry,
            "properties": {
                "Class": row['Class']
            }
        }
        geojson_features.append(feature)

# Create the GeoJSON structure
geojson = {
    "type": "FeatureCollection",
    "features": geojson_features
}

# Extract geometries and properties for GeoDataFrame
geometries = [feature['geometry'] for feature in geojson['features']]
properties = [feature['properties'] for feature in geojson['features']]

# Create a GeoDataFrame using the geometries and properties
gdf_final = gpd.GeoDataFrame(properties, geometry=geometries, crs="EPSG:4326")

# Transform the GeoDataFrame to EPSG:3857 (Web Mercator)
gdf_final = gdf_final.to_crs(epsg=3857)

# Save the GeoDataFrame as a shapefile
gdf_final.to_file(f'{csv_basename}.shp')

# %%
"""Zip the shapefiles"""
# Out:
# 'Zip the shapefiles'

# %%
# Create ZIP file
zip_filename = f"{csv_basename}_shapefiles.zip"
shapefile_files = glob.glob(f"{csv_basename}.*")

# %%
# Exclude the .csv file from the list of files to be zipped
shapefile_files = [file for file in shapefile_files if not file.endswith('.csv')]

# Create the ZIP archive
with zipfile.ZipFile(zip_filename, "w") as zipf:
    for file in shapefile_files:
        zipf.write(file, os.path.basename(file))

print(f"Created ZIP file: {zip_filename}")

# Delete the original shapefile files after zipping, but keep the .csv file
for file in shapefile_files:
    os.remove(file)
    print(f"Deleted: {file}")

print("All shapefile components have been deleted after zipping, except for the .csv file.")
# Out:
# Created ZIP file: Masalia_full_shapefiles.zip
# Deleted: Masalia_full.prj
# Deleted: Masalia_full.cpg
# Deleted: Masalia_full.shx
# Deleted: Masalia_full.shp
# Deleted: Masalia_full.dbf
# All shapefile components have been deleted after zipping, except for the .csv file.

# %% [markdown]
# # Add Buffer to combine nearby predicted objects

# %%
pwd
# Out:
# '/home/core-stack/Documents/Ponds'

# %%
ZOOM_LEVEL = 17
EARTH_CIRCUMFERENCE_DEGREES = 360  # degrees

# %%
# Load the CSV file
csv_filepath = 'Masalia_full.csv'
df = pd.read_csv(csv_filepath)

df.rename(columns={'Predicted Class': 'Class'}, inplace=True)

# %%
# Extract the base name dynamically (e.g., "TRY" from "TRY.csv")
csv_basename = os.path.splitext(os.path.basename(csv_filepath))[0]

csv_basename
# Out:
# 'Masalia_full'

# %%
# Function to convert pixel coordinates to geo-coordinates
def pixel_to_geo(x, y, lat_top_left, lon_top_left, lat_bottom_right, lon_bottom_right, img_width, img_height):
    lon_range = lon_bottom_right - lon_top_left
    lat_range = lat_top_left - lat_bottom_right  # Latitude decreases southward
    lon = lon_top_left + (x / img_width) * lon_range
    lat = lat_top_left - (y / img_height) * lat_range
    return lon, lat

# Initialize an empty list for GeoJSON features
geojson_features = []

# Iterate through each row
for _, row in df.iterrows():
    lat_top_left = row['Top Left Latitude']
    lon_top_left = row['Top Left Longitude']
    lat_bottom_right = row['Bottom Right Latitude']
    lon_bottom_right = row['Bottom Right Longitude']

    tile_width, tile_height = 256, 256

    object_coords = []

    # Iterate over all possible coordinate columns dynamically
    i = 1
    while True:
        x_col = f'X_{i}'
        y_col = f'Y_{i}'

        if x_col not in row or y_col not in row:
            break  # Stop if columns don't exist

        x = row[x_col]
        y = row[y_col]

        if pd.notna(x) and pd.notna(y):
            lon, lat = pixel_to_geo(x, y, lat_top_left, lon_top_left, lat_bottom_right, lon_bottom_right, tile_width, tile_height)
            if np.isfinite(lon) and np.isfinite(lat):
                object_coords.append((lon, lat))
        else:
            break  # Stop when NaN values appear

        i += 1  # Move to the next set of coordinates

    # Ensure the polygon has at least 3 points before adding
    if len(object_coords) >= 3:
        object_coords.append(object_coords[0])  # Close the polygon
        polygon_geometry = Polygon(object_coords)
        feature = {
            "type": "Feature",
            "geometry": polygon_geometry,
            "properties": {
                "Class": row['Class']
            }
        }
        geojson_features.append(feature)

# Convert to GeoDataFrame
gdf_final = gpd.GeoDataFrame(
    [feature['properties'] for feature in geojson_features],
    geometry=[feature['geometry'] for feature in geojson_features],
    crs="EPSG:4326"
)

# Merge overlapping geometries
from shapely.ops import unary_union

buffer_distance = 0.0005  # Adjust as needed
gdf_final['Buffered'] = gdf_final.geometry.buffer(buffer_distance)
combined_polygons = unary_union(gdf_final['Buffered'])
combined_polygons = combined_polygons.buffer(-buffer_distance)

# Convert back to GeoDataFrame
gdf_combined = gpd.GeoDataFrame(geometry=[combined_polygons], crs="EPSG:4326")

# Save the final shapefile
csv_basename = os.path.splitext(os.path.basename(csv_filepath))[0]
gdf_combined.to_file(f"{csv_basename}_COMBINED_GEOMETRY.shp")
# Out:
# /tmp/ipykernel_27422/2232150949.py:68: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_final['Buffered'] = gdf_final.geometry.buffer(buffer_distance)

# %%
"""Zip the shapefiles"""
# Out:
# 'Zip the shapefiles'

# %%
zip_filename = f"{csv_basename}_COMBINED_GEOMETRY.zip"
shapefile_files = glob.glob(f"{csv_basename}_COMBINED_GEOMETRY.*")

# %%
# Exclude the .csv file from the list of files to be zipped
shapefile_files = [file for file in shapefile_files if not file.endswith('.csv')]

# Create the ZIP archive
with zipfile.ZipFile(zip_filename, "w") as zipf:
    for file in shapefile_files:
        zipf.write(file, os.path.basename(file))

print(f"Created ZIP file: {zip_filename}")

# Delete the original shapefile files after zipping, but keep the .csv file
for file in shapefile_files:
    os.remove(file)
    print(f"Deleted: {file}")

print("All shapefile components have been deleted after zipping, except for the .csv file.")
# Out:
# Created ZIP file: Masalia_full_COMBINED_GEOMETRY.zip
# Deleted: Masalia_full_COMBINED_GEOMETRY.prj
# Deleted: Masalia_full_COMBINED_GEOMETRY.cpg
# Deleted: Masalia_full_COMBINED_GEOMETRY.shx
# Deleted: Masalia_full_COMBINED_GEOMETRY.dbf
# Deleted: Masalia_full_COMBINED_GEOMETRY.shp
# All shapefile components have been deleted after zipping, except for the .csv file.

# %%
##test
