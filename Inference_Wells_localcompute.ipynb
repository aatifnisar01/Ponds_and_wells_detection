# %% [markdown]
# # Necessary Steps

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#!pip install -U ultralytics

# %%
import json
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import shutil
from random import choice
import re
import csv
import zipfile
import pandas as pd
import glob
import math
import geopandas as gpd
from shapely.geometry import shape
from shapely.geometry import Polygon
from ultralytics import YOLO
from PIL import Image
import requests
import time
import os
from ultralytics import YOLO
from skimage.filters.rank import entropy
from skimage.morphology import disk
from skimage.util import img_as_ubyte
from shapely.geometry import box

# %%
cd /home/core-stack/Documents/Ponds
# Out:
# /home/core-stack/Documents/Ponds

# %%
pwd = os.getcwd()
pwd
# Out:
# '/home/core-stack/Documents/Ponds'

# %% [markdown]
# # Download Data for Inference

# %%
pwd

# %% [raw]
# Get Bounding boxes automatically from GeoJSON instead of manually drawing on GEE

# %%
gdf = gpd.read_file("Shapefiles/Masalia_mws.geojson")

# %%
# Compute the bounding box
minx, miny, maxx, maxy = gdf.total_bounds

# Create a bounding box polygon
bounding_box = gpd.GeoDataFrame(geometry=[box(minx, miny, maxx, maxy)], crs=gdf.crs)

# Plot the geometry and the updated bounding box
fig, ax = plt.subplots(figsize=(10, 6))
gdf.plot(ax=ax, color="blue", alpha=0.5, edgecolor="black")
bounding_box.plot(ax=ax, edgecolor="red", facecolor="none", linewidth=2)

plt.show()

# %%
# Get the bounding box coordinates
minx, miny, maxx, maxy = gdf.total_bounds

# Define bounding box points
topLeft = [minx, maxy]
topRight = [maxx, maxy]
bottomRight = [maxx, miny]
bottomLeft = [minx, miny]

# Print the coordinates
print(f"topLeft = {topLeft}")
print(f"topRight = {topRight}")
print(f"bottomRight = {bottomRight}")
print(f"bottomLeft = {bottomLeft}")

# %% [markdown]
# NOT NEEDED ANYMORE - Give coordinated of the bounding box drawn on GEE

# %%
"""
#coords for the bounding box (boipariguda)
topLeft = [82.07347488402685,18.57110542069261]
topRight = [82.60081863402685,18.57110542069261]
bottomRight = [82.60081863402685,18.9572939770273]
bottomLeft = [82.07347488402685,18.9572939770273]
"""

# %% [markdown]
# Zoom Level and folder name, where the output (image tiles) will be saved

# %%
zoom_level = 18      # Zoom level
output_folder = "Data/Zoom18/Masalia"

# %%
def deg2num(lat_deg, lon_deg, zoom):
    lat_rad = math.radians(lat_deg)
    n = 2.0 ** zoom
    xtile = int((lon_deg + 180.0) / 360.0 * n)
    ytile = int((1.0 - math.log(math.tan(lat_rad) + (1 / math.cos(lat_rad))) / math.pi) / 2.0 * n)
    return (xtile, ytile)

def getCoords(zoomLevel):
    topleft = deg2num(topLeft[1], topLeft[0], zoomLevel)  # (c,b)
    topright = deg2num(topRight[1], topRight[0], zoomLevel)  # (a,b)
    bottomright = deg2num(bottomRight[1], bottomRight[0], zoomLevel)  # (a,d)
    bottomleft = deg2num(bottomLeft[1], bottomLeft[0], zoomLevel)  # (c,d)
    xmin = min(topleft[0], topright[0], bottomleft[0], bottomright[0])
    xmax = max(topleft[0], topright[0], bottomleft[0], bottomright[0])
    ymin = min(topleft[1], topright[1], bottomleft[1], bottomright[1])
    ymax = max(topleft[1], topright[1], bottomleft[1], bottomright[1])
    return (xmin, xmax, ymin, ymax)

def download_map_tiles(base_url, output_folder, zoom_level, scale):
    # Ensure output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Get start time
    start_time = time.time()

    # Iterate over each tile within the specified range
    xmin, xmax, ymin, ymax = getCoords(zoom_level)
    for x in range(xmin, xmax + 1):
        for y in range(ymin, ymax + 1):
            # Construct the URL for the current tile with scale=3 for 640x640
            tile_url = f"{base_url}&x={x}&y={y}&z={zoom_level}&scale={scale}"
            print(tile_url)
            try:
                # Send HTTP GET request to fetch the tile
                response = requests.get(tile_url)

                # Check if request was successful (status code 200)
                if response.status_code == 200:
                    # Save the tile image to a file in the output folder
                    filename = f"tile_{zoom_level}_{x}_{y}.png"
                    filepath = os.path.join(output_folder, filename)
                    with open(filepath, "wb") as f:
                        f.write(response.content)
                    print(f"Downloaded: {filename}")
                else:
                    print(f"Failed to download tile ({x}, {y}), HTTP status code: {response.status_code}")

            except Exception as e:
                print(f"Error downloading tile ({x}, {y}): {e}")

    # Get end time
    end_time = time.time()

    # Print the total execution time
    print(f"Total time taken: {end_time - start_time} seconds")

# %%
base_url = "https://mt1.google.com/vt/lyrs=s"
scale = 1           # scale of 1 = 256*256 dimensional image

if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Created the folder: {output_folder}")
else:
    print(f"The folder already exists: {output_folder}")

# %%
download_map_tiles(base_url, output_folder, zoom_level, scale)

# %% [markdown]
# # SAVE PREDICTIONS IN CSV

# %%
pwd
# Out:
# '/home/core-stack/Documents/Ponds'

# %% [markdown]
# Initialize model and parameters

# %%
model_path = "Models/Wells_best.pt"
model_path = os.path.join(pwd, model_path)

image_dir = "Data/Zoom18/Masalia"
#image_dir = os.path.join(pwd, image_dir)

csv_file = "CSV_Output/Masalia_Wells.csv"

zoom  = 18

# %%
# Define class-specific confidence thresholds
conf_thresholds = {
    'Wells': 0.71,
}

# Class names (ensure these match the order used in your model training)
class_names = [
    'Wells',

]

# Mapping of class names to abbreviations
class_abbreviations = {
    'Wells': 'W',

}

# %% [markdown]
# Load the model

# %%
my_new_model = YOLO(model_path)

# %% [markdown]
# FUNCTIONS

# %%
def process_image(image_path, conf_thresholds):
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to load image {image_path}")
        return None, None, None, None, None

    results = my_new_model.predict(img)

    polygons = []
    pred_classes = []
    conf_scores = []

    if results[0].masks is not None:
        for i, (polygon, cls, conf) in enumerate(zip(results[0].masks.xy, results[0].boxes.cls.cpu().numpy(), results[0].boxes.conf.cpu().numpy())):
            class_name = class_names[int(cls)]
            if conf >= conf_thresholds[class_name]:
                polygons.append(polygon)
                pred_classes.append(class_name)
                conf_scores.append(conf)

    # Print only when detections are made
    if len(polygons) == 0:
        print(f"No detections in {image_path}")
    else:
        print(f"Detections found in {image_path}: {len(polygons)} polygons")

    return image_path, len(polygons), polygons, pred_classes, conf_scores


def extract_xtile_ytile(image_path):
    try:
        basename = os.path.basename(image_path)
        parts = basename.split('_')
        if len(parts) >= 4:
            xtile = int(parts[2])
            ytile = int(parts[3].split('.')[0].split()[0])
            return xtile, ytile
        else:
            raise ValueError("Filename does not contain valid tile coordinates")
    except Exception as e:
        raise ValueError(f"Filename {image_path} does not contain valid tile coordinates: {e}")


def tile_corners_to_latlon(xtile, ytile, zoom):
    n = 2.0 ** zoom
    lon_deg = xtile / n * 360.0 - 180.0
    lat_rad_nw = math.atan(math.sinh(math.pi * (1 - 2 * (ytile / n))))
    lat_deg_nw = math.degrees(lat_rad_nw)

    lat_rad_se = math.atan(math.sinh(math.pi * (1 - 2 * ((ytile + 1) / n))))
    lat_deg_se = math.degrees(lat_rad_se)

    lat_deg_nw = max(min(lat_deg_nw, 85.0511), -85.0511)
    lat_deg_se = max(min(lat_deg_se, 85.0511), -85.0511)

    top_left = (lat_deg_nw, lon_deg)
    top_right = (lat_deg_nw, lon_deg + (360.0 / n))
    bottom_right = (lat_deg_se, lon_deg + (360.0 / n))
    bottom_left = (lat_deg_se, lon_deg)

    return top_left, top_right, bottom_left, bottom_right

def calculate_tile_center(top_left, top_right, bottom_left, bottom_right):
    center_lat = (top_left[0] + bottom_left[0]) / 2
    center_lon = (top_left[1] + top_right[1]) / 2
    return (center_lat, center_lon)

# %% [markdown]
# Predictions

# %%
image_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if os.path.isfile(os.path.join(image_dir, f))]

# %%
len(image_files)
# Out:
# 75626

# %%
# Start timing
start_time = time.time()

max_vertices = 0
for image_path in image_files:
    _, _, polygons, _, _ = process_image(image_path, conf_thresholds)
    for polygon in polygons:
        max_vertices = max(max_vertices, len(polygon))

with open(csv_file, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    header = ["Image Path", "Predicted Class", "Center Latitude", "Center Longitude",
              "Top Left Latitude", "Top Left Longitude", "Top Right Latitude", "Top Right Longitude",
              "Bottom Left Latitude", "Bottom Left Longitude", "Bottom Right Latitude", "Bottom Right Longitude"]
    for i in range(1, max_vertices + 1):
        header.extend([f'X_{i}', f'Y_{i}'])
    csvwriter.writerow(header)

    for image_path in image_files:
        try:
            image_path, num_polygons, polygons, pred_classes, _ = process_image(image_path, conf_thresholds)
            if image_path is None:
                continue

            xtile, ytile = extract_xtile_ytile(image_path)
            top_left, top_right, bottom_left, bottom_right = tile_corners_to_latlon(xtile, ytile, zoom)
            latitude, longitude = calculate_tile_center(top_left, top_right, bottom_left, bottom_right)

            for pred_class, polygon in zip(pred_classes, polygons):
                row = [image_path, pred_class, latitude, longitude, top_left[0], top_left[1], top_right[0], top_right[1],
                       bottom_left[0], bottom_left[1], bottom_right[0], bottom_right[1]]
                for point in polygon:
                    row.extend([point[0], point[1]])
                csvwriter.writerow(row)
        except ValueError as e:
            print(e)
            continue

# End timing
end_time = time.time()

# Print the time taken
time_taken = end_time - start_time
print(f"CSV file '{csv_file}' saved successfully.")
print(f"Time taken to complete: {time_taken:.2f} seconds.")
# Out:
# 0: 256x256 (no detections), 12.2ms
# Speed: 2.4ms preprocess, 12.2ms inference, 32.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194552_112843.png
#
# 0: 256x256 (no detections), 12.4ms
# Speed: 0.6ms preprocess, 12.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194501_112943.png
#
# 0: 256x256 (no detections), 12.3ms
# Speed: 0.4ms preprocess, 12.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194664_112877.png
#
# 0: 256x256 (no detections), 13.1ms
# Speed: 0.5ms preprocess, 13.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194592_113016.png
#
# 0: 256x256 (no detections), 18.9ms
# Speed: 0.5ms preprocess, 18.9ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194583_112869.png
#
# 0: 256x256 (no detections), 18.1ms
# Speed: 0.5ms preprocess, 18.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194462_112868.png
#
# 0: 256x256 (no detections), 14.0ms
# Speed: 0.6ms preprocess, 14.0ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194648_113018.png
#
# 0: 256x256 (no detections), 13.3ms
# Speed: 0.5ms preprocess, 13.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194399_112982.png
#
# 0: 256x256 (no detections), 15.7ms
# Speed: 0.5ms preprocess, 15.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194532_112975.png
#
# 0: 256x256 (no detections), 14.7ms
# Speed: 0.5ms preprocess, 14.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194461_113020.png
#
# 0: 256x256 (no detections), 15.3ms
# Speed: 0.5ms preprocess, 15.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194507_113032.png
#
# 0: 256x256 (no detections), 20.2ms
# Speed: 0.5ms preprocess, 20.2ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194600_112906.png
#
# 0: 256x256 (no detections), 18.8ms
# Speed: 0.5ms preprocess, 18.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194362_113019.png
#
# 0: 256x256 (no detections), 19.1ms
# Speed: 0.5ms preprocess, 19.1ms inference, 5.2ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194611_112893.png
#
# 0: 256x256 (no detections), 26.3ms
# Speed: 0.5ms preprocess, 26.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194663_112996.png
#
# 0: 256x256 (no detections), 25.4ms
# Speed: 0.5ms preprocess, 25.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194658_112957.png
#
# 0: 256x256 (no detections), 15.8ms
# Speed: 2.5ms preprocess, 15.8ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194598_113026.png
#
# 0: 256x256 (no detections), 22.3ms
# Speed: 0.5ms preprocess, 22.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194490_112908.png
#
# 0: 256x256 (no detections), 15.0ms
# Speed: 0.5ms preprocess, 15.0ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194646_113030.png
#
# 0: 256x256 1 Wells, 16.4ms
# Speed: 0.6ms preprocess, 16.4ms inference, 97.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194505_112920.png
#
# 0: 256x256 (no detections), 15.7ms
# Speed: 0.5ms preprocess, 15.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194658_112948.png
#
# 0: 256x256 (no detections), 16.9ms
# Speed: 0.5ms preprocess, 16.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194579_113055.png
#
# 0: 256x256 1 Wells, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 26.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194486_112950.png
#
# 0: 256x256 (no detections), 24.0ms
# Speed: 0.7ms preprocess, 24.0ms inference, 4.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194501_112969.png
#
# 0: 256x256 1 Wells, 20.7ms
# Speed: 0.5ms preprocess, 20.7ms inference, 3.2ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194449_112911.png
#
# 0: 256x256 (no detections), 14.6ms
# Speed: 0.4ms preprocess, 14.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194608_113039.png
#
# 0: 256x256 (no detections), 17.2ms
# Speed: 0.5ms preprocess, 17.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194466_112932.png
#
# 0: 256x256 (no detections), 15.5ms
# Speed: 0.5ms preprocess, 15.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194559_112893.png
#
# 0: 256x256 (no detections), 14.8ms
# Speed: 0.5ms preprocess, 14.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194473_112910.png
#
# 0: 256x256 3 Wellss, 30.3ms
# Speed: 0.5ms preprocess, 30.3ms inference, 6.1ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194596_112848.png
#
# 0: 256x256 (no detections), 24.9ms
# Speed: 0.4ms preprocess, 24.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194596_112934.png
#
# 0: 256x256 (no detections), 14.6ms
# Speed: 0.7ms preprocess, 14.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194539_113021.png
#
# 0: 256x256 (no detections), 12.3ms
# Speed: 0.5ms preprocess, 12.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194436_112841.png
#
# 0: 256x256 (no detections), 15.0ms
# Speed: 0.5ms preprocess, 15.0ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194600_112918.png
#
# 0: 256x256 (no detections), 13.7ms
# Speed: 0.5ms preprocess, 13.7ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194545_112883.png
#
# 0: 256x256 (no detections), 13.2ms
# Speed: 0.5ms preprocess, 13.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194563_112897.png
#
# 0: 256x256 (no detections), 18.1ms
# Speed: 0.5ms preprocess, 18.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194622_113000.png
#
# 0: 256x256 (no detections), 13.7ms
# Speed: 1.7ms preprocess, 13.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194616_112958.png
#
# 0: 256x256 1 Wells, 13.1ms
# Speed: 0.5ms preprocess, 13.1ms inference, 1.9ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194593_112876.png
#
# 0: 256x256 1 Wells, 13.5ms
# Speed: 0.4ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194398_112844.png
#
# 0: 256x256 (no detections), 14.1ms
# Speed: 0.5ms preprocess, 14.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194441_112863.png
#
# 0: 256x256 (no detections), 26.2ms
# Speed: 0.5ms preprocess, 26.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194484_113027.png
#
# 0: 256x256 1 Wells, 13.7ms
# Speed: 0.5ms preprocess, 13.7ms inference, 1.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194383_112872.png
#
# 0: 256x256 (no detections), 13.8ms
# Speed: 0.4ms preprocess, 13.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194473_112838.png
#
# 0: 256x256 (no detections), 26.7ms
# Speed: 0.5ms preprocess, 26.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194677_112938.png
#
# 0: 256x256 (no detections), 17.3ms
# Speed: 0.5ms preprocess, 17.3ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194398_112838.png
#
# 0: 256x256 1 Wells, 14.8ms
# Speed: 0.5ms preprocess, 14.8ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
# Detections found in Data/Zoom18/Masalia/tile_18_194410_112858.png: 1 polygons
#
# 0: 256x256 (no detections), 14.6ms
# Speed: 0.6ms preprocess, 14.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194659_112862.png
#
# 0: 256x256 (no detections), 15.6ms
# Speed: 0.5ms preprocess, 15.6ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194517_113064.png
#
# 0: 256x256 (no detections), 15.9ms
# Speed: 0.5ms preprocess, 15.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194482_112858.png
#
# 0: 256x256 (no detections), 12.1ms
# Speed: 0.6ms preprocess, 12.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194393_112844.png
#
# 0: 256x256 1 Wells, 12.4ms
# Speed: 1.1ms preprocess, 12.4ms inference, 1.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194364_112937.png
#
# 0: 256x256 (no detections), 23.9ms
# Speed: 0.4ms preprocess, 23.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194569_112858.png
#
# 0: 256x256 (no detections), 26.6ms
# Speed: 0.6ms preprocess, 26.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194674_112877.png
#
# 0: 256x256 1 Wells, 25.5ms
# Speed: 0.5ms preprocess, 25.5ms inference, 2.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194630_113056.png
#
# 0: 256x256 1 Wells, 27.3ms
# Speed: 0.5ms preprocess, 27.3ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194477_112929.png
#
# 0: 256x256 (no detections), 36.7ms
# Speed: 0.8ms preprocess, 36.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194515_112888.png
#
# 0: 256x256 (no detections), 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194427_113059.png
#
# 0: 256x256 (no detections), 14.1ms
# Speed: 1.7ms preprocess, 14.1ms inference, 1.9ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194467_112999.png
#
# 0: 256x256 (no detections), 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194549_112835.png
#
# 0: 256x256 1 Wells, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# Detections found in Data/Zoom18/Masalia/tile_18_194480_112949.png: 1 polygons
#
# 0: 256x256 (no detections), 17.3ms
# Speed: 0.4ms preprocess, 17.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194526_113003.png
#
# 0: 256x256 (no detections), 22.0ms
# Speed: 0.5ms preprocess, 22.0ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194386_112942.png
#
# 0: 256x256 (no detections), 25.9ms
# Speed: 1.3ms preprocess, 25.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194470_113016.png
#
# 0: 256x256 (no detections), 12.8ms
# Speed: 0.5ms preprocess, 12.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194633_112928.png
#
# 0: 256x256 (no detections), 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194616_112877.png
#
# 0: 256x256 (no detections), 12.8ms
# Speed: 0.5ms preprocess, 12.8ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194629_112855.png
#
# 0: 256x256 (no detections), 14.3ms
# Speed: 0.5ms preprocess, 14.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194538_113034.png
#
# 0: 256x256 (no detections), 15.3ms
# Speed: 0.5ms preprocess, 15.3ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194641_112838.png
#
# 0: 256x256 (no detections), 31.5ms
# Speed: 0.5ms preprocess, 31.5ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194589_112991.png
#
# 0: 256x256 (no detections), 23.2ms
# Speed: 0.5ms preprocess, 23.2ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194631_112985.png
#
# 0: 256x256 (no detections), 15.5ms
# Speed: 0.5ms preprocess, 15.5ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194615_113038.png
#
# 0: 256x256 (no detections), 16.8ms
# Speed: 1.5ms preprocess, 16.8ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194555_112861.png
#
# 0: 256x256 (no detections), 16.1ms
# Speed: 0.6ms preprocess, 16.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194529_113008.png
#
# 0: 256x256 (no detections), 15.2ms
# Speed: 0.5ms preprocess, 15.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194438_112942.png
#
# 0: 256x256 1 Wells, 17.0ms
# Speed: 0.5ms preprocess, 17.0ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194387_112849.png
#
# 0: 256x256 (no detections), 14.9ms
# Speed: 0.5ms preprocess, 14.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194583_112883.png
#
# 0: 256x256 (no detections), 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194489_113061.png
#
# 0: 256x256 (no detections), 20.0ms
# Speed: 0.5ms preprocess, 20.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194431_112966.png
#
# 0: 256x256 (no detections), 16.1ms
# Speed: 0.5ms preprocess, 16.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194661_112843.png
#
# 0: 256x256 (no detections), 13.0ms
# Speed: 0.5ms preprocess, 13.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194374_112924.png
#
# 0: 256x256 (no detections), 14.8ms
# Speed: 0.5ms preprocess, 14.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194388_113047.png
#
# 0: 256x256 (no detections), 35.5ms
# Speed: 0.6ms preprocess, 35.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194566_113028.png
#
# 0: 256x256 (no detections), 15.2ms
# Speed: 0.5ms preprocess, 15.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194485_113010.png
#
# 0: 256x256 1 Wells, 18.6ms
# Speed: 0.9ms preprocess, 18.6ms inference, 1.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194407_112888.png
#
# 0: 256x256 (no detections), 16.3ms
# Speed: 0.4ms preprocess, 16.3ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194568_113011.png
#
# 0: 256x256 (no detections), 19.2ms
# Speed: 0.5ms preprocess, 19.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194477_112994.png
#
# 0: 256x256 (no detections), 17.1ms
# Speed: 0.5ms preprocess, 17.1ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194654_112852.png
#
# 0: 256x256 (no detections), 17.1ms
# Speed: 0.5ms preprocess, 17.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194651_112837.png
#
# 0: 256x256 1 Wells, 16.3ms
# Speed: 0.5ms preprocess, 16.3ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 256)
# Detections found in Data/Zoom18/Masalia/tile_18_194401_113047.png: 1 polygons
#
# 0: 256x256 (no detections), 14.6ms
# Speed: 0.5ms preprocess, 14.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194383_112878.png
#
# 0: 256x256 (no detections), 14.7ms
# Speed: 0.5ms preprocess, 14.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194487_112899.png
#
# 0: 256x256 (no detections), 16.2ms
# Speed: 0.7ms preprocess, 16.2ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194529_112984.png
#
# 0: 256x256 (no detections), 17.6ms
# Speed: 0.5ms preprocess, 17.6ms inference, 8.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194475_112989.png
#
# 0: 256x256 (no detections), 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194480_112991.png
#
# 0: 256x256 1 Wells, 14.6ms
# Speed: 0.5ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194652_112842.png
#
# 0: 256x256 (no detections), 15.0ms
# Speed: 0.4ms preprocess, 15.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194489_112919.png
#
# 0: 256x256 (no detections), 14.5ms
# Speed: 0.5ms preprocess, 14.5ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194680_112914.png
#
# 0: 256x256 (no detections), 13.4ms
# Speed: 0.5ms preprocess, 13.4ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194530_112866.png
#
# 0: 256x256 (no detections), 13.5ms
# Speed: 0.5ms preprocess, 13.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194607_112937.png
#
# 0: 256x256 (no detections), 14.0ms
# Speed: 0.5ms preprocess, 14.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194364_113021.png
#
# 0: 256x256 (no detections), 13.7ms
# Speed: 0.5ms preprocess, 13.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194674_113030.png
#
# 0: 256x256 (no detections), 14.0ms
# Speed: 0.5ms preprocess, 14.0ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194396_112960.png
#
# 0: 256x256 (no detections), 14.6ms
# Speed: 0.5ms preprocess, 14.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194650_112873.png
#
# 0: 256x256 (no detections), 18.5ms
# Speed: 0.5ms preprocess, 18.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194545_113017.png
#
# 0: 256x256 (no detections), 15.1ms
# Speed: 0.6ms preprocess, 15.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194629_112954.png
#
# 0: 256x256 (no detections), 16.7ms
# Speed: 0.5ms preprocess, 16.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194368_113007.png
#
# 0: 256x256 (no detections), 15.8ms
# Speed: 0.5ms preprocess, 15.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194553_113055.png
#
# 0: 256x256 (no detections), 22.3ms
# Speed: 0.5ms preprocess, 22.3ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194627_112919.png
#
# 0: 256x256 (no detections), 30.3ms
# Speed: 0.5ms preprocess, 30.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194658_112932.png
#
# 0: 256x256 2 Wellss, 16.5ms
# Speed: 0.7ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194503_112921.png
#
# 0: 256x256 (no detections), 17.7ms
# Speed: 0.5ms preprocess, 17.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194596_113002.png
#
# 0: 256x256 (no detections), 15.1ms
# Speed: 0.5ms preprocess, 15.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194599_112930.png
#
# 0: 256x256 1 Wells, 26.2ms
# Speed: 0.5ms preprocess, 26.2ms inference, 4.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194484_112917.png
#
# 0: 256x256 (no detections), 37.1ms
# Speed: 0.5ms preprocess, 37.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194628_112897.png
#
# 0: 256x256 (no detections), 15.2ms
# Speed: 0.5ms preprocess, 15.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194659_112989.png
#
# 0: 256x256 (no detections), 13.6ms
# Speed: 0.5ms preprocess, 13.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194676_112956.png
#
# 0: 256x256 (no detections), 20.7ms
# Speed: 0.6ms preprocess, 20.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194541_112977.png
#
# 0: 256x256 (no detections), 14.2ms
# Speed: 0.6ms preprocess, 14.2ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194601_112939.png
#
# 0: 256x256 1 Wells, 19.6ms
# Speed: 0.5ms preprocess, 19.6ms inference, 2.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194629_113031.png
#
# 0: 256x256 (no detections), 15.7ms
# Speed: 0.4ms preprocess, 15.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194670_112835.png
#
# 0: 256x256 (no detections), 37.3ms
# Speed: 0.8ms preprocess, 37.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194624_112986.png
#
# 0: 256x256 (no detections), 13.8ms
# Speed: 0.5ms preprocess, 13.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194521_112874.png
#
# 0: 256x256 1 Wells, 14.0ms
# Speed: 0.6ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194425_112851.png
#
# 0: 256x256 (no detections), 13.7ms
# Speed: 0.4ms preprocess, 13.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194447_113006.png
#
# 0: 256x256 (no detections), 14.6ms
# Speed: 0.5ms preprocess, 14.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194379_112917.png
#
# 0: 256x256 (no detections), 17.6ms
# Speed: 0.9ms preprocess, 17.6ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194638_112963.png
#
# 0: 256x256 (no detections), 14.9ms
# Speed: 0.5ms preprocess, 14.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194483_112945.png
#
# 0: 256x256 (no detections), 14.6ms
# Speed: 0.5ms preprocess, 14.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194615_112998.png
#
# 0: 256x256 (no detections), 18.5ms
# Speed: 0.5ms preprocess, 18.5ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194541_112970.png
#
# 0: 256x256 1 Wells, 19.4ms
# Speed: 0.5ms preprocess, 19.4ms inference, 1.9ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194387_112961.png
#
# 0: 256x256 (no detections), 15.4ms
# Speed: 0.4ms preprocess, 15.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194534_112946.png
#
# 0: 256x256 (no detections), 15.4ms
# Speed: 0.5ms preprocess, 15.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194487_112931.png
#
# 0: 256x256 (no detections), 16.5ms
# Speed: 0.5ms preprocess, 16.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194676_113050.png
#
# 0: 256x256 (no detections), 14.9ms
# Speed: 0.5ms preprocess, 14.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194437_112961.png
#
# 0: 256x256 (no detections), 13.8ms
# Speed: 0.5ms preprocess, 13.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194558_113049.png
#
# 0: 256x256 (no detections), 13.7ms
# Speed: 0.5ms preprocess, 13.7ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194371_112865.png
#
# 0: 256x256 2 Wellss, 15.2ms
# Speed: 0.5ms preprocess, 15.2ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194583_112993.png
#
# 0: 256x256 (no detections), 15.6ms
# Speed: 0.4ms preprocess, 15.6ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194524_112964.png
#
# 0: 256x256 (no detections), 14.2ms
# Speed: 0.5ms preprocess, 14.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194377_112978.png
#
# 0: 256x256 (no detections), 13.6ms
# Speed: 0.5ms preprocess, 13.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194651_112843.png
#
# 0: 256x256 (no detections), 13.3ms
# Speed: 0.5ms preprocess, 13.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194598_113020.png
#
# 0: 256x256 2 Wellss, 39.0ms
# Speed: 0.5ms preprocess, 39.0ms inference, 7.0ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194543_112896.png
#
# 0: 256x256 (no detections), 16.8ms
# Speed: 0.5ms preprocess, 16.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194510_112951.png
#
# 0: 256x256 (no detections), 15.7ms
# Speed: 0.5ms preprocess, 15.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194432_113014.png
#
# 0: 256x256 (no detections), 21.9ms
# Speed: 0.5ms preprocess, 21.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194361_112879.png
#
# 0: 256x256 (no detections), 27.5ms
# Speed: 0.5ms preprocess, 27.5ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194648_112854.png
#
# 0: 256x256 (no detections), 30.9ms
# Speed: 0.5ms preprocess, 30.9ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194551_113024.png
#
# 0: 256x256 (no detections), 18.5ms
# Speed: 0.8ms preprocess, 18.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194412_112926.png
#
# 0: 256x256 (no detections), 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194444_113020.png
#
# 0: 256x256 (no detections), 13.6ms
# Speed: 0.5ms preprocess, 13.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194415_112900.png
#
# 0: 256x256 (no detections), 13.9ms
# Speed: 0.5ms preprocess, 13.9ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194677_112896.png
#
# 0: 256x256 1 Wells, 22.2ms
# Speed: 0.5ms preprocess, 22.2ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194629_112908.png
#
# 0: 256x256 (no detections), 14.1ms
# Speed: 0.5ms preprocess, 14.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194497_112985.png
#
# 0: 256x256 3 Wellss, 13.7ms
# Speed: 0.6ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194664_113056.png
#
# 0: 256x256 (no detections), 13.5ms
# Speed: 0.5ms preprocess, 13.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194492_112876.png
#
# 0: 256x256 3 Wellss, 13.7ms
# Speed: 0.5ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194371_113019.png
#
# 0: 256x256 1 Wells, 13.4ms
# Speed: 0.4ms preprocess, 13.4ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194378_112982.png
#
# 0: 256x256 (no detections), 14.7ms
# Speed: 0.4ms preprocess, 14.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194580_112858.png
#
# 0: 256x256 (no detections), 14.3ms
# Speed: 0.5ms preprocess, 14.3ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194675_113010.png
#
# 0: 256x256 (no detections), 14.4ms
# Speed: 0.5ms preprocess, 14.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194501_112926.png
#
# 0: 256x256 (no detections), 23.6ms
# Speed: 0.5ms preprocess, 23.6ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194424_113030.png
#
# 0: 256x256 (no detections), 17.1ms
# Speed: 0.5ms preprocess, 17.1ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194524_113001.png
#
# 0: 256x256 (no detections), 22.8ms
# Speed: 0.5ms preprocess, 22.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194591_113041.png
#
# 0: 256x256 (no detections), 14.9ms
# Speed: 1.1ms preprocess, 14.9ms inference, 4.1ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194416_112903.png
#
# 0: 256x256 (no detections), 15.3ms
# Speed: 0.5ms preprocess, 15.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194367_113036.png
#
# 0: 256x256 1 Wells, 15.6ms
# Speed: 0.6ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194584_112875.png
#
# 0: 256x256 (no detections), 14.8ms
# Speed: 0.4ms preprocess, 14.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194559_112892.png
#
# 0: 256x256 (no detections), 16.2ms
# Speed: 0.5ms preprocess, 16.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194408_112865.png
#
# 0: 256x256 (no detections), 16.7ms
# Speed: 0.6ms preprocess, 16.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194524_112923.png
#
# 0: 256x256 (no detections), 23.9ms
# Speed: 0.5ms preprocess, 23.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194621_113041.png
#
# 0: 256x256 (no detections), 13.2ms
# Speed: 0.5ms preprocess, 13.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194417_112953.png
#
# 0: 256x256 1 Wells, 13.9ms
# Speed: 0.5ms preprocess, 13.9ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194377_112900.png
#
# 0: 256x256 (no detections), 14.2ms
# Speed: 1.7ms preprocess, 14.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194571_113013.png
#
# 0: 256x256 (no detections), 15.0ms
# Speed: 0.5ms preprocess, 15.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194396_113001.png
#
# 0: 256x256 (no detections), 14.0ms
# Speed: 0.5ms preprocess, 14.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194390_112961.png
#
# 0: 256x256 (no detections), 17.7ms
# Speed: 0.5ms preprocess, 17.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194586_112936.png
#
# 0: 256x256 (no detections), 13.7ms
# Speed: 0.5ms preprocess, 13.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194635_112889.png
#
# 0: 256x256 (no detections), 13.3ms
# Speed: 0.5ms preprocess, 13.3ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194367_113026.png
#
# 0: 256x256 (no detections), 14.8ms
# Speed: 0.5ms preprocess, 14.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194540_113063.png
#
# 0: 256x256 (no detections), 15.1ms
# Speed: 0.5ms preprocess, 15.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194612_113042.png
#
# 0: 256x256 (no detections), 17.7ms
# Speed: 1.2ms preprocess, 17.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194605_112992.png
#
# 0: 256x256 (no detections), 15.0ms
# Speed: 0.5ms preprocess, 15.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194430_113007.png
#
# 0: 256x256 (no detections), 14.4ms
# Speed: 0.5ms preprocess, 14.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194396_112989.png
#
# 0: 256x256 (no detections), 13.6ms
# Speed: 0.5ms preprocess, 13.6ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194559_112961.png
#
# 0: 256x256 2 Wellss, 14.4ms
# Speed: 0.8ms preprocess, 14.4ms inference, 2.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194611_112934.png
#
# 0: 256x256 (no detections), 17.6ms
# Speed: 0.5ms preprocess, 17.6ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194527_112966.png
#
# 0: 256x256 (no detections), 20.0ms
# Speed: 0.5ms preprocess, 20.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194440_112890.png
#
# 0: 256x256 (no detections), 12.6ms
# Speed: 0.5ms preprocess, 12.6ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194612_112887.png
#
# 0: 256x256 (no detections), 14.3ms
# Speed: 0.6ms preprocess, 14.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194391_113033.png
#
# 0: 256x256 (no detections), 15.7ms
# Speed: 0.5ms preprocess, 15.7ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194516_112895.png
#
# 0: 256x256 (no detections), 15.0ms
# Speed: 0.4ms preprocess, 15.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194612_112959.png
#
# 0: 256x256 (no detections), 14.6ms
# Speed: 0.5ms preprocess, 14.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194579_113028.png
#
# 0: 256x256 1 Wells, 13.5ms
# Speed: 0.6ms preprocess, 13.5ms inference, 1.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194491_112843.png
#
# 0: 256x256 1 Wells, 15.9ms
# Speed: 0.4ms preprocess, 15.9ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194404_112966.png
#
# 0: 256x256 (no detections), 14.6ms
# Speed: 0.4ms preprocess, 14.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194594_112919.png
#
# 0: 256x256 (no detections), 13.7ms
# Speed: 0.5ms preprocess, 13.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194670_112946.png
#
# 0: 256x256 1 Wells, 13.1ms
# Speed: 0.5ms preprocess, 13.1ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# Detections found in Data/Zoom18/Masalia/tile_18_194455_113060.png: 1 polygons
#
# 0: 256x256 (no detections), 13.7ms
# Speed: 1.2ms preprocess, 13.7ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194669_112894.png
#
# 0: 256x256 (no detections), 12.8ms
# Speed: 0.5ms preprocess, 12.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194429_112889.png
#
# 0: 256x256 1 Wells, 12.4ms
# Speed: 1.3ms preprocess, 12.4ms inference, 1.9ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194409_112980.png
#
# 0: 256x256 (no detections), 13.6ms
# Speed: 0.4ms preprocess, 13.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194627_112928.png
#
# 0: 256x256 (no detections), 14.2ms
# Speed: 0.5ms preprocess, 14.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194681_112876.png
#
# 0: 256x256 (no detections), 17.4ms
# Speed: 0.7ms preprocess, 17.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194494_112885.png
#
# 0: 256x256 (no detections), 14.4ms
# Speed: 0.9ms preprocess, 14.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194544_113033.png
#
# 0: 256x256 (no detections), 20.4ms
# Speed: 0.5ms preprocess, 20.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194424_112860.png
#
# 0: 256x256 (no detections), 14.1ms
# Speed: 0.5ms preprocess, 14.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194446_112966.png
#
# 0: 256x256 1 Wells, 12.6ms
# Speed: 0.5ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194373_112939.png
#
# 0: 256x256 (no detections), 14.1ms
# Speed: 0.4ms preprocess, 14.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194516_112950.png
#
# 0: 256x256 (no detections), 13.1ms
# Speed: 0.5ms preprocess, 13.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194513_112938.png
#
# 0: 256x256 (no detections), 15.6ms
# Speed: 0.6ms preprocess, 15.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194591_112998.png
#
# 0: 256x256 1 Wells, 15.0ms
# Speed: 0.5ms preprocess, 15.0ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194358_112893.png
#
# 0: 256x256 (no detections), 19.3ms
# Speed: 0.5ms preprocess, 19.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194595_112985.png
#
# 0: 256x256 (no detections), 27.9ms
# Speed: 1.7ms preprocess, 27.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194587_112952.png
#
# 0: 256x256 (no detections), 14.3ms
# Speed: 0.5ms preprocess, 14.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194418_112978.png
#
# 0: 256x256 (no detections), 14.1ms
# Speed: 0.5ms preprocess, 14.1ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194542_112940.png
#
# 0: 256x256 (no detections), 13.1ms
# Speed: 1.6ms preprocess, 13.1ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194509_112942.png
#
# 0: 256x256 (no detections), 13.6ms
# Speed: 0.5ms preprocess, 13.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194438_112845.png
#
# 0: 256x256 1 Wells, 17.1ms
# Speed: 0.5ms preprocess, 17.1ms inference, 1.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194476_112845.png
#
# 0: 256x256 (no detections), 19.4ms
# Speed: 0.4ms preprocess, 19.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194399_113004.png
#
# 0: 256x256 (no detections), 15.0ms
# Speed: 0.6ms preprocess, 15.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194376_112989.png
#
# 0: 256x256 (no detections), 16.7ms
# Speed: 0.7ms preprocess, 16.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194384_112958.png
#
# 0: 256x256 (no detections), 14.6ms
# Speed: 0.5ms preprocess, 14.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194577_113034.png
#
# 0: 256x256 1 Wells, 16.9ms
# Speed: 2.7ms preprocess, 16.9ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194608_112983.png
#
# 0: 256x256 (no detections), 13.9ms
# Speed: 0.4ms preprocess, 13.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194537_112991.png
#
# 0: 256x256 (no detections), 12.7ms
# Speed: 1.4ms preprocess, 12.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194666_112971.png
#
# 0: 256x256 (no detections), 12.5ms
# Speed: 0.5ms preprocess, 12.5ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194540_112860.png
#
# 0: 256x256 (no detections), 12.4ms
# Speed: 0.6ms preprocess, 12.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194374_112851.png
#
# 0: 256x256 1 Wells, 13.3ms
# Speed: 0.4ms preprocess, 13.3ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194582_113034.png
#
# 0: 256x256 (no detections), 14.4ms
# Speed: 0.4ms preprocess, 14.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194367_112940.png
#
# 0: 256x256 (no detections), 14.1ms
# Speed: 0.5ms preprocess, 14.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194589_112945.png
#
# 0: 256x256 (no detections), 15.3ms
# Speed: 0.5ms preprocess, 15.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194512_113036.png
#
# 0: 256x256 (no detections), 14.0ms
# Speed: 0.4ms preprocess, 14.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194372_112894.png
#
# 0: 256x256 (no detections), 19.2ms
# Speed: 0.5ms preprocess, 19.2ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194590_112954.png
#
# 0: 256x256 (no detections), 26.3ms
# Speed: 0.4ms preprocess, 26.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194510_113035.png
#
# 0: 256x256 (no detections), 14.7ms
# Speed: 0.5ms preprocess, 14.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194371_112853.png
#
# 0: 256x256 (no detections), 15.4ms
# Speed: 0.5ms preprocess, 15.4ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194528_112921.png
#
# 0: 256x256 (no detections), 27.7ms
# Speed: 0.5ms preprocess, 27.7ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194407_112968.png
#
# 0: 256x256 (no detections), 21.4ms
# Speed: 0.5ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194420_112993.png
#
# 0: 256x256 (no detections), 14.1ms
# Speed: 0.6ms preprocess, 14.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194620_112903.png
#
# 0: 256x256 (no detections), 15.9ms
# Speed: 0.5ms preprocess, 15.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194560_112895.png
#
# 0: 256x256 (no detections), 14.9ms
# Speed: 0.5ms preprocess, 14.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194620_113034.png
#
# 0: 256x256 (no detections), 12.5ms
# Speed: 0.5ms preprocess, 12.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194437_113010.png
#
# 0: 256x256 (no detections), 14.2ms
# Speed: 0.5ms preprocess, 14.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194576_113036.png
#
# 0: 256x256 (no detections), 22.6ms
# Speed: 0.5ms preprocess, 22.6ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194565_112908.png
#
# 0: 256x256 1 Wells, 19.6ms
# Speed: 0.6ms preprocess, 19.6ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194549_112937.png
#
# ...
# No detections in Data/Zoom18/Masalia/tile_18_194597_112994.png
#
# 0: 256x256 (no detections), 27.2ms
# Speed: 0.5ms preprocess, 27.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194486_113030.png
#
# 0: 256x256 (no detections), 26.5ms
# Speed: 0.5ms preprocess, 26.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194642_112902.png
#
# 0: 256x256 (no detections), 20.2ms
# Speed: 0.5ms preprocess, 20.2ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194600_113041.png
#
# 0: 256x256 (no detections), 12.6ms
# Speed: 0.5ms preprocess, 12.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194413_112900.png
#
# 0: 256x256 (no detections), 21.2ms
# Speed: 0.5ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194415_113034.png
#
# 0: 256x256 1 Wells, 11.9ms
# Speed: 0.8ms preprocess, 11.9ms inference, 3.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194411_113016.png
#
# 0: 256x256 (no detections), 16.2ms
# Speed: 0.5ms preprocess, 16.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194425_112953.png
#
# 0: 256x256 1 Wells, 16.2ms
# Speed: 1.1ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194489_112923.png
#
# 0: 256x256 (no detections), 16.5ms
# Speed: 1.3ms preprocess, 16.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194655_112873.png
#
# 0: 256x256 (no detections), 15.8ms
# Speed: 0.5ms preprocess, 15.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194596_112917.png
#
# 0: 256x256 (no detections), 12.9ms
# Speed: 0.5ms preprocess, 12.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194664_113012.png
#
# 0: 256x256 1 Wells, 12.9ms
# Speed: 0.4ms preprocess, 12.9ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194405_112859.png
#
# 0: 256x256 (no detections), 12.7ms
# Speed: 0.4ms preprocess, 12.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194643_112858.png
#
# 0: 256x256 (no detections), 19.6ms
# Speed: 0.4ms preprocess, 19.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194673_113004.png
#
# 0: 256x256 1 Wells, 21.3ms
# Speed: 0.5ms preprocess, 21.3ms inference, 1.9ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194483_112843.png
#
# 0: 256x256 (no detections), 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194410_112929.png
#
# 0: 256x256 (no detections), 25.1ms
# Speed: 0.4ms preprocess, 25.1ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194596_113042.png
#
# 0: 256x256 (no detections), 32.1ms
# Speed: 0.9ms preprocess, 32.1ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194573_112846.png
#
# 0: 256x256 (no detections), 17.7ms
# Speed: 0.5ms preprocess, 17.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194363_113006.png
#
# 0: 256x256 (no detections), 27.7ms
# Speed: 0.5ms preprocess, 27.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194576_112862.png
#
# 0: 256x256 (no detections), 18.3ms
# Speed: 0.5ms preprocess, 18.3ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194523_112954.png
#
# 0: 256x256 (no detections), 14.2ms
# Speed: 0.5ms preprocess, 14.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194637_112937.png
#
# 0: 256x256 1 Wells, 16.1ms
# Speed: 0.5ms preprocess, 16.1ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194392_112868.png
#
# 0: 256x256 (no detections), 15.0ms
# Speed: 0.5ms preprocess, 15.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194658_112883.png
#
# 0: 256x256 (no detections), 14.3ms
# Speed: 0.5ms preprocess, 14.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194525_112840.png
#
# 0: 256x256 (no detections), 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194640_112850.png
#
# 0: 256x256 (no detections), 11.6ms
# Speed: 0.5ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194426_112952.png
#
# 0: 256x256 1 Wells, 12.2ms
# Speed: 0.4ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194413_112897.png
#
# 0: 256x256 (no detections), 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194512_112838.png
#
# 0: 256x256 (no detections), 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194566_112841.png
#
# 0: 256x256 (no detections), 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194637_112910.png
#
# 0: 256x256 1 Wells, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194430_112898.png
#
# 0: 256x256 (no detections), 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194411_112862.png
#
# 0: 256x256 (no detections), 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194676_113041.png
#
# 0: 256x256 (no detections), 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194480_112999.png
#
# 0: 256x256 (no detections), 15.6ms
# Speed: 0.4ms preprocess, 15.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194558_112962.png
#
# 0: 256x256 (no detections), 20.8ms
# Speed: 0.5ms preprocess, 20.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194568_113002.png
#
# 0: 256x256 (no detections), 12.2ms
# Speed: 0.4ms preprocess, 12.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194500_112921.png
#
# 0: 256x256 (no detections), 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194561_112887.png
#
# 0: 256x256 (no detections), 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194559_112862.png
#
# 0: 256x256 1 Wells, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194499_113009.png
#
# 0: 256x256 (no detections), 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194489_113037.png
#
# 0: 256x256 (no detections), 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194636_112978.png
#
# 0: 256x256 1 Wells, 12.5ms
# Speed: 0.4ms preprocess, 12.5ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194544_112840.png
#
# 0: 256x256 (no detections), 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194455_112871.png
#
# 0: 256x256 (no detections), 11.6ms
# Speed: 0.4ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194681_112904.png
#
# 0: 256x256 (no detections), 12.1ms
# Speed: 0.4ms preprocess, 12.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194550_112873.png
#
# 0: 256x256 1 Wells, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194381_113046.png
#
# 0: 256x256 1 Wells, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194527_112897.png
#
# 0: 256x256 1 Wells, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194657_112906.png
#
# 0: 256x256 (no detections), 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194637_112842.png
#
# 0: 256x256 (no detections), 16.2ms
# Speed: 0.5ms preprocess, 16.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194518_113040.png
#
# 0: 256x256 2 Wellss, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194477_112878.png
#
# 0: 256x256 (no detections), 14.0ms
# Speed: 0.4ms preprocess, 14.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194435_112994.png
#
# 0: 256x256 (no detections), 12.1ms
# Speed: 0.4ms preprocess, 12.1ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194544_112909.png
#
# 0: 256x256 1 Wells, 11.6ms
# Speed: 0.4ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194568_112994.png
#
# 0: 256x256 (no detections), 11.6ms
# Speed: 0.4ms preprocess, 11.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194397_112864.png
#
# 0: 256x256 (no detections), 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194357_112937.png
#
# 0: 256x256 (no detections), 12.7ms
# Speed: 0.4ms preprocess, 12.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194450_112851.png
#
# 0: 256x256 (no detections), 18.7ms
# Speed: 0.4ms preprocess, 18.7ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194540_112985.png
#
# 0: 256x256 (no detections), 14.7ms
# Speed: 0.4ms preprocess, 14.7ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194441_112956.png
#
# 0: 256x256 (no detections), 27.7ms
# Speed: 1.1ms preprocess, 27.7ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194629_112899.png
#
# 0: 256x256 (no detections), 15.2ms
# Speed: 1.5ms preprocess, 15.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194615_113032.png
#
# 0: 256x256 (no detections), 17.6ms
# Speed: 0.7ms preprocess, 17.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194446_112917.png
#
# 0: 256x256 (no detections), 16.0ms
# Speed: 0.4ms preprocess, 16.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194648_113029.png
#
# 0: 256x256 (no detections), 14.5ms
# Speed: 0.6ms preprocess, 14.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194555_113034.png
#
# 0: 256x256 (no detections), 13.2ms
# Speed: 0.8ms preprocess, 13.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194436_113030.png
#
# 0: 256x256 (no detections), 19.6ms
# Speed: 0.7ms preprocess, 19.6ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194473_113006.png
#
# 0: 256x256 (no detections), 18.4ms
# Speed: 0.5ms preprocess, 18.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194621_112938.png
#
# 0: 256x256 1 Wells, 28.2ms
# Speed: 0.5ms preprocess, 28.2ms inference, 2.2ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194470_112975.png
#
# 0: 256x256 1 Wells, 13.4ms
# Speed: 0.5ms preprocess, 13.4ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194450_113019.png
#
# 0: 256x256 (no detections), 18.2ms
# Speed: 0.4ms preprocess, 18.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194561_113058.png
#
# 0: 256x256 1 Wells, 22.6ms
# Speed: 0.4ms preprocess, 22.6ms inference, 1.8ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194513_112993.png
#
# 0: 256x256 (no detections), 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194439_113014.png
#
# 0: 256x256 1 Wells, 13.1ms
# Speed: 0.4ms preprocess, 13.1ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194482_112893.png
#
# 0: 256x256 (no detections), 17.8ms
# Speed: 0.4ms preprocess, 17.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194611_112925.png
#
# 0: 256x256 (no detections), 14.2ms
# Speed: 0.4ms preprocess, 14.2ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194599_112970.png
#
# 0: 256x256 (no detections), 12.4ms
# Speed: 0.4ms preprocess, 12.4ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194461_112991.png
#
# 0: 256x256 (no detections), 11.5ms
# Speed: 0.4ms preprocess, 11.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194448_112862.png
#
# 0: 256x256 1 Wells, 11.6ms
# Speed: 0.3ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194457_112838.png
#
# 0: 256x256 1 Wells, 12.9ms
# Speed: 0.4ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 256)
# No detections in Data/Zoom18/Masalia/tile_18_194629_113009.png
#
# 0: 256x256 (no detections), 13.3ms
# Speed: 0.4ms preprocess, 13.3ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 256)

# %% [markdown]
# # Convert to Geometry

# %%
pwd
# Out:
# '/home/core-stack/Documents/Ponds'

# %%
# Constants
ZOOM_LEVEL = 18
EARTH_CIRCUMFERENCE_DEGREES = 360  # degrees

# %%
# Load the CSV file
df = pd.read_csv("CSV_Output/Masalia_Wells.csv")

df.rename(columns={'Predicted Class': 'Class'}, inplace=True)

# %%
def degrees_per_pixel(zoom):
    total_pixels = 256 * (2 ** zoom)
    return EARTH_CIRCUMFERENCE_DEGREES / total_pixels

def pixel_to_geo(x, y, lat_top_left, lon_top_left, lat_bottom_right, lon_bottom_right, img_width, img_height):
    lon_range = lon_bottom_right - lon_top_left
    lat_range = lat_top_left - lat_bottom_right  # Note: latitude decreases as you go south
    lon = lon_top_left + (x / img_width) * lon_range
    lat = lat_top_left - (y / img_height) * lat_range  # y increases downward in image coordinates
    return lon, lat

# Find the maximum index for X_n and Y_n columns
x_columns = [col for col in df.columns if col.startswith('X_')]
if x_columns:
    max_index = max(int(col.split('_')[1]) for col in x_columns)
else:
    max_index = 0  # If no X_n columns are found

# Initialize an empty list to store GeoJSON features
geojson_features = []

# Iterate over each row in the dataframe
for index, row in df.iterrows():
    lat_top_left = row['Top Left Latitude']
    lon_top_left = row['Top Left Longitude']
    lat_bottom_right = row['Bottom Right Latitude']
    lon_bottom_right = row['Bottom Right Longitude']

    tile_width, tile_height = 256, 256
    object_coords = []

    for i in range(1, max_index + 1):  # Dynamically set the range
        x_col = f'X_{i}'
        y_col = f'Y_{i}'
        if x_col in row and y_col in row:
            x = row[x_col]
            y = row[y_col]
            if pd.notna(x) and pd.notna(y):
                lon, lat = pixel_to_geo(x, y, lat_top_left, lon_top_left, lat_bottom_right, lon_bottom_right, tile_width, tile_height)
                if np.isfinite(lon) and np.isfinite(lat):
                    object_coords.append((lon, lat))

        if pd.isna(x) or pd.isna(y) or i == max_index:
            if object_coords:  
                centroid_lon = np.mean([coord[0] for coord in object_coords])
                centroid_lat = np.mean([coord[1] for coord in object_coords])
                centroid = Point(centroid_lon, centroid_lat)

                feature = {
                    "type": "Feature",
                    "geometry": centroid,
                    "properties": {"Class": row['Class']}
                }
                geojson_features.append(feature)
            object_coords = []

# Create a GeoDataFrame
geometries = [feature['geometry'] for feature in geojson_features]
properties = [feature['properties'] for feature in geojson_features]
gdf_final = gpd.GeoDataFrame(properties, geometry=geometries, crs="EPSG:4326")

# Transform and save
gdf_final = gdf_final.to_crs(epsg=3857)
gdf_final.to_file('Shapefile_OutputMasalia_Wells.shp')

# Print verification
print(gdf_final.head())
print(degrees_per_pixel(17))
# Out:
#    Class                         geometry
# 0  Wells  POINT (9682854.935 2784435.227)
# 1  Wells  POINT (9693560.896 2770428.142)
# 2  Wells  POINT (9681388.797 2755531.779)
# 3  Wells  POINT (9689764.842 2753536.693)
# 4  Wells   POINT (9696670.629 2756560.11)
# 1.0728836059570312e-05
